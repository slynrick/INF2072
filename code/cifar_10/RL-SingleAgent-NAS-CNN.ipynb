# %%
# Import necessary libraries
import tensorflow as tf
from keras import layers, models, optimizers
from keras.datasets import cifar10
from keras.utils import to_categorical
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.model_selection import train_test_split

# %%
# Set random seeds for reproducibility
np.random.seed(int(time.time()))
random.seed(int(time.time()))
tf.random.set_seed(int(time.time()))

# %%
# Load CIFAR-10 dataset
(input_train, label_train), (input_test, label_test) = cifar10.load_data()
input_train, input_test = input_train / 255.0, input_test / 255.0  # Normalize to [0, 1]
label_train, label_test = to_categorical(label_train), to_categorical(label_test)

# Split training data into training and validation sets
train_data, val_data, train_labels, val_labels = train_test_split(
    input_train, label_train, test_size=0.2, stratify=label_train, random_state=random.randint(0, 1000)
)

# %%
print(train_data.shape)
print(val_data.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def sample_subset(data, labels, num_samples_per_class):
    sampled_data = []
    sampled_labels = []
    for class_idx in range(labels.shape[1]):  # Iterate over each class
        class_mask = labels[:, class_idx] == 1  # Find samples of the current class
        class_data = data[class_mask]
        class_labels = labels[class_mask]
        
        # Randomly sample the specified number of samples
        indices = np.random.choice(len(class_data), num_samples_per_class, replace=False)
        sampled_data.append(class_data[indices])
        sampled_labels.append(class_labels[indices])
    
    # Concatenate all sampled data and labels
    return np.concatenate(sampled_data), np.concatenate(sampled_labels)

# %%
# Hiperparâmetros
num_layers = 5  # Número de camadas ocultas
alpha = 0.1  # Learning rate
gamma = 0.9  # Discount factor
epsilon = 0.9  # Initial exploration rate
epsilon_decay = 0.995
min_epsilon = 0.01
num_episodes = 1000  # Número de episódios para treinar o agente

input_channels = 3  # For RGB images
num_classes = 10  # Example for CIFAR-10
batch_size = 32
input_shape = (batch_size, 32, 32, 3,)

patience = 5
rl_epochs = 30  # Número de épocas para treinar a rede com os dados da memória
retrain_patience = 10
retrain_epochs = 200  # Número de épocas para treinar a rede com os dados da memória

# %%
functions = [
    'no_op',
    'vgg_block_3x3', 'vgg_block_5x5',
    'resnet_block_3x3', 'resnet_block_5x5',
    'inception_block_3x3', 'inception_block_5x5',
    'densenet_block_3x3', 'densenet_block_5x5'
]
functions_size = len(functions)

# %%
# Define block implementations
def vgg_block(input_tensor, filters, kernel_size, layer_name):
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='relu', name=f"{layer_name}_1")(input_tensor)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_1")(x)  # Add Batch Normalization
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='relu', name=f"{layer_name}_2")(x)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_2")(x)  # Add Batch Normalization
    x = layers.MaxPooling2D(pool_size=(2, 2), name=f"{layer_name}_3")(x)
    return x

def resnet_block(input_tensor, filters, kernel_size, layer_name):
    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), padding='same', name=f"{layer_name}_1")(input_tensor)
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='relu', name=f"{layer_name}_2")(input_tensor)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_1")(x)  # Add Batch Normalization
    x = layers.Conv2D(filters, kernel_size, padding='same', name=f"{layer_name}_3")(x)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_2")(x)  # Add Batch Normalization
    x = layers.Add(name=f"{layer_name}_4")([x, shortcut])
    x = layers.Activation('relu', name=f"{layer_name}_5")(x)
    return x

def inception_block(input_tensor, kernel_size, layer_name):
    branch1 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_1")(input_tensor)
    branch2 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_2")(input_tensor)
    branch2 = layers.Conv2D(64, kernel_size, padding='same', activation='relu', name=f"{layer_name}_3")(branch2)
    branch3 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_4")(input_tensor)
    branch3 = layers.Conv2D(64, kernel_size=(kernel_size[0] + 2, kernel_size[1] + 2), padding='same', activation='relu', name=f"{layer_name}_5")(branch3)
    branch4 = layers.MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same', name=f"{layer_name}_6")(input_tensor)
    branch4 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_7")(branch4)
    return layers.Concatenate(name=f"{layer_name}_8")([branch1, branch2, branch3, branch4])

def densenet_block(input_tensor, filters, kernel_size, layer_name):
    x = layers.Conv2D(filters, kernel_size, padding='same', name=f"{layer_name}_1")(input_tensor)
    x = layers.BatchNormalization(name=f"{layer_name}_2")(x)
    x = layers.ReLU(name=f"{layer_name}_3")(x)
    return layers.Concatenate(name=f"{layer_name}_4")([input_tensor, x])

# Define CNN model
def build_cnn(layers_config, input_shape, num_classes):
    input_tensor = layers.Input(shape=input_shape[1:], name="input")
    x = input_tensor
    for idx, layer in enumerate(layers_config):
        if layer == 'vgg_block_3x3':
            x = vgg_block(x, 64, (3, 3), layer_name=f"vgg_block_3x3_{idx}")
        elif layer == 'vgg_block_5x5':
            x = vgg_block(x, 64, (5, 5), layer_name=f"vgg_block_5x5_{idx}")
        elif layer == 'resnet_block_3x3':
            x = resnet_block(x, 64, (3, 3), layer_name=f"resnet_block_3x3_{idx}")
        elif layer == 'resnet_block_5x5':
            x = resnet_block(x, 64, (5, 5), layer_name=f"resnet_block_5x5_{idx}")
        elif layer == 'inception_block_3x3':
            x = inception_block(x, (3, 3), layer_name=f"inception_block_3x3_{idx}")
        elif layer == 'inception_block_5x5':
            x = inception_block(x, (5, 5), layer_name=f"inception_block_5x5_{idx}")
        elif layer == 'densenet_block_3x3':
            x = densenet_block(x, 32, (3, 3), layer_name=f"densenet_block_3x3_{idx}")
        elif layer == 'densenet_block_5x5':
            x = densenet_block(x, 32, (5, 5), layer_name=f"densenet_block_5x5_{idx}")
        elif layer == 'no_op':
            x = layers.Lambda(lambda y: y, name=f"ide_{idx}")(x)
    x = layers.Flatten(name="flatten")(x)
    output_tensor = layers.Dense(num_classes, activation='softmax', name="output")(x)
    model = models.Model(inputs=[input_tensor], outputs=[output_tensor], name='cnn_model')
    model.compile(optimizer=optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
class CNNEnv:
    def __init__(self, input_shape, num_classes, num_layers):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.layers_str = ['no_op'] * num_layers
        self.current_layer_index = 0
        self.evaluation_cache = {}

    def reset(self):
        self.layers_str = ['no_op'] * self.num_layers
        self.current_layer_index = 0
        return self.get_state()

    def step(self, action):
        self.layers_str[self.current_layer_index] = functions[action]
        next_state = self.get_state()
        layers_tuple = tuple(self.layers_str)
        if layers_tuple in self.evaluation_cache:
            reward = self.evaluation_cache[layers_tuple]
        else:
            reward = self.evaluate()
            self.evaluation_cache[layers_tuple] = reward
        self.current_layer_index += 1
        done = self.current_layer_index >= self.num_layers
        return next_state, reward, done, self.current_layer_index

    def get_state(self):
        return tuple(self.layers_str)

    def evaluate(self):

        # Sample 1000 random samples per class for training
        subsample_train_data, subsample_train_labels = sample_subset(train_data, train_labels, 1000)

        # Sample 250 random samples per class for validation
        subsample_val_data, subsample_val_labels = sample_subset(val_data, val_labels, 250)

        model = build_cnn(self.layers_str, self.input_shape, self.num_classes)
        
        # Early stopping callback
        early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='val_loss', 
            patience=retrain_patience, 
            restore_best_weights=True
        )
        
        history = model.fit(
            subsample_train_data, 
            subsample_train_labels,
            validation_data=(subsample_val_data, subsample_val_labels), 
            callbacks=[early_stopping],
            epochs=rl_epochs, 
            batch_size=batch_size, 
            verbose=0
        )
        
        val_accuracy = max(history.history['val_accuracy'])
        return val_accuracy

# %%
# Initialize the environment
env = CNNEnv(input_shape, num_classes, num_layers)

# Initialize Q-table for the single agent
q_table = {}

# RL
for episode in range(num_episodes):
    state = env.reset()
    done = False
    current_layer = 0

    all_rewards = []
    while not done:
        if state not in q_table:
            q_table[state] = np.zeros(len(functions))
            
        # Choose an action using epsilon-greedy policy
        if random.random() > epsilon:
            action = np.argmax(q_table[state])
        else:
            action = random.randint(0, len(functions) - 1)

        # Take the action and observe the next state and reward
        next_state, reward_acc, done, next_layer = env.step(action)

        print(f"Accuracy Reward: {reward_acc:.4f} | Architecture: {env.layers_str}")

        reward = reward_acc  # Use accuracy as the primary reward

        all_rewards.append(reward)
        
        if next_state not in q_table:
            q_table[next_state] = np.zeros(len(functions))

        # Update the Q-table
        if next_layer < num_layers:
            q_table[state][action] += alpha * (
                reward + gamma * np.max(q_table[next_state]) * (1 - done) - q_table[state][action]
            )

        # Move to the next state
        state = next_state
        current_layer = next_layer

    # Decay epsilon
    epsilon = max(min_epsilon, epsilon * epsilon_decay)

    # Log episode results
    print(f"Episode: {episode + 1}, Epsilon: {epsilon:.4f}, Max Reward: {np.max(all_rewards):.4f}, Mean Reward: {np.mean(all_rewards):.4f}, Accumulated Reward: {np.sum(all_rewards):.4f}")
# Out:
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5228 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5228 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5892 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.5844 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'vgg_block_3x3', 'resnet_block_3x3']
# Episode: 1, Epsilon: 0.8955, Max Reward: 0.5892, Mean Reward: 0.5510, Accumulated Reward: 2.7552
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5356 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5624 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'densenet_block_3x3', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.5140 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'densenet_block_3x3', 'densenet_block_3x3', 'resnet_block_3x3']
# Episode: 2, Epsilon: 0.8910, Max Reward: 0.5624, Mean Reward: 0.5386, Accumulated Reward: 2.6928
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5372 | Architecture: ['resnet_block_5x5', 'no_op', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5372 | Architecture: ['resnet_block_5x5', 'no_op', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4976 | Architecture: ['resnet_block_5x5', 'no_op', 'densenet_block_5x5', 'no_op', 'inception_block_3x3']
# Episode: 3, Epsilon: 0.8866, Max Reward: 0.5372, Mean Reward: 0.5288, Accumulated Reward: 2.6440
# Accuracy Reward: 0.5112 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5100 | Architecture: ['inception_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4688 | Architecture: ['inception_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5076 | Architecture: ['inception_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.4972 | Architecture: ['inception_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'inception_block_3x3', 'inception_block_5x5']
# Episode: 4, Epsilon: 0.8821, Max Reward: 0.5112, Mean Reward: 0.4990, Accumulated Reward: 2.4948
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5280 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5740 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5436 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'resnet_block_5x5', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.6532 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'resnet_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3']
# Episode: 5, Epsilon: 0.8777, Max Reward: 0.6532, Mean Reward: 0.5574, Accumulated Reward: 2.7868
# Accuracy Reward: 0.5064 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5148 | Architecture: ['inception_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5024 | Architecture: ['inception_block_3x3', 'inception_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5288 | Architecture: ['inception_block_3x3', 'inception_block_3x3', 'resnet_block_3x3', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.4964 | Architecture: ['inception_block_3x3', 'inception_block_3x3', 'resnet_block_3x3', 'inception_block_5x5', 'resnet_block_3x3']
# Episode: 6, Epsilon: 0.8733, Max Reward: 0.5288, Mean Reward: 0.5098, Accumulated Reward: 2.5488
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5228 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5704 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6312 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6488 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'vgg_block_3x3']
# Episode: 7, Epsilon: 0.8690, Max Reward: 0.6488, Mean Reward: 0.5818, Accumulated Reward: 2.9092
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5584 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5456 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4912 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.5100 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'resnet_block_3x3']
# Episode: 8, Epsilon: 0.8646, Max Reward: 0.5584, Mean Reward: 0.5254, Accumulated Reward: 2.6272
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5584 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5456 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5812 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.5592 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'vgg_block_5x5', 'densenet_block_5x5']
# Episode: 9, Epsilon: 0.8603, Max Reward: 0.5812, Mean Reward: 0.5533, Accumulated Reward: 2.7664
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5124 | Architecture: ['resnet_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5148 | Architecture: ['resnet_block_5x5', 'resnet_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5020 | Architecture: ['resnet_block_5x5', 'resnet_block_5x5', 'densenet_block_5x5', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5448 | Architecture: ['resnet_block_5x5', 'resnet_block_5x5', 'densenet_block_5x5', 'densenet_block_5x5', 'vgg_block_3x3']
# Episode: 10, Epsilon: 0.8560, Max Reward: 0.5448, Mean Reward: 0.5220, Accumulated Reward: 2.6100
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5576 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5560 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6660 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'densenet_block_5x5', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6640 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'densenet_block_5x5', 'vgg_block_5x5', 'vgg_block_3x3']
# Episode: 11, Epsilon: 0.8517, Max Reward: 0.6660, Mean Reward: 0.5959, Accumulated Reward: 2.9796
# Accuracy Reward: 0.5112 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5428 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6212 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5992 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6420 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'densenet_block_5x5']
# Episode: 12, Epsilon: 0.8475, Max Reward: 0.6420, Mean Reward: 0.5833, Accumulated Reward: 2.9164
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5164 | Architecture: ['densenet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5164 | Architecture: ['densenet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5324 | Architecture: ['densenet_block_5x5', 'resnet_block_3x3', 'no_op', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5324 | Architecture: ['densenet_block_5x5', 'resnet_block_3x3', 'no_op', 'densenet_block_5x5', 'no_op']
# Episode: 13, Epsilon: 0.8432, Max Reward: 0.5324, Mean Reward: 0.5171, Accumulated Reward: 2.5856
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4816 | Architecture: ['densenet_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5332 | Architecture: ['densenet_block_5x5', 'densenet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5636 | Architecture: ['densenet_block_5x5', 'densenet_block_5x5', 'vgg_block_3x3', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5636 | Architecture: ['densenet_block_5x5', 'densenet_block_5x5', 'vgg_block_3x3', 'inception_block_5x5', 'no_op']
# Episode: 14, Epsilon: 0.8390, Max Reward: 0.5636, Mean Reward: 0.5260, Accumulated Reward: 2.6300
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5108 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4920 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'resnet_block_5x5', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.5116 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'resnet_block_5x5', 'inception_block_3x3', 'inception_block_5x5']
# Episode: 15, Epsilon: 0.8348, Max Reward: 0.5360, Mean Reward: 0.5150, Accumulated Reward: 2.5748
# Accuracy Reward: 0.5112 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5428 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5644 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5644 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5644 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op']
# Episode: 16, Epsilon: 0.8306, Max Reward: 0.5644, Mean Reward: 0.5494, Accumulated Reward: 2.7472
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5388 | Architecture: ['densenet_block_5x5', 'no_op', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5216 | Architecture: ['densenet_block_5x5', 'no_op', 'inception_block_3x3', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5084 | Architecture: ['densenet_block_5x5', 'no_op', 'inception_block_3x3', 'densenet_block_5x5', 'densenet_block_5x5']
# Episode: 17, Epsilon: 0.8265, Max Reward: 0.5388, Mean Reward: 0.5090, Accumulated Reward: 2.5448
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5280 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5764 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5496 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'resnet_block_3x3', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.6364 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3']
# Episode: 18, Epsilon: 0.8224, Max Reward: 0.6364, Mean Reward: 0.5557, Accumulated Reward: 2.7784
# Accuracy Reward: 0.5112 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5428 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5764 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5764 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5328 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'no_op', 'inception_block_3x3']
# Episode: 19, Epsilon: 0.8182, Max Reward: 0.5764, Mean Reward: 0.5479, Accumulated Reward: 2.7396
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5744 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5744 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5720 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.5748 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'inception_block_3x3', 'densenet_block_3x3']
# Episode: 20, Epsilon: 0.8141, Max Reward: 0.5748, Mean Reward: 0.5635, Accumulated Reward: 2.8176
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5280 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5280 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6396 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6492 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'resnet_block_5x5']
# Episode: 21, Epsilon: 0.8101, Max Reward: 0.6492, Mean Reward: 0.5666, Accumulated Reward: 2.8328
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5164 | Architecture: ['densenet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5164 | Architecture: ['densenet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5164 | Architecture: ['densenet_block_5x5', 'resnet_block_3x3', 'no_op', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.5164 | Architecture: ['densenet_block_5x5', 'resnet_block_3x3', 'no_op', 'resnet_block_5x5', 'no_op']
# Episode: 22, Epsilon: 0.8060, Max Reward: 0.5164, Mean Reward: 0.5107, Accumulated Reward: 2.5536
# Accuracy Reward: 0.5112 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5540 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5056 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5276 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'resnet_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6264 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'resnet_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3']
# Episode: 23, Epsilon: 0.8020, Max Reward: 0.6264, Mean Reward: 0.5450, Accumulated Reward: 2.7248
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5440 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5652 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5756 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.5756 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'no_op']
# Episode: 24, Epsilon: 0.7980, Max Reward: 0.5756, Mean Reward: 0.5565, Accumulated Reward: 2.7824
# Accuracy Reward: 0.3596 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4644 | Architecture: ['no_op', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5628 | Architecture: ['no_op', 'densenet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5904 | Architecture: ['no_op', 'densenet_block_3x3', 'vgg_block_3x3', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5792 | Architecture: ['no_op', 'densenet_block_3x3', 'vgg_block_3x3', 'inception_block_5x5', 'densenet_block_5x5']
# Episode: 25, Epsilon: 0.7940, Max Reward: 0.5904, Mean Reward: 0.5113, Accumulated Reward: 2.5564
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5400 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5996 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5996 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6140 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'resnet_block_5x5']
# Episode: 26, Epsilon: 0.7900, Max Reward: 0.6140, Mean Reward: 0.5750, Accumulated Reward: 2.8752
# Accuracy Reward: 0.4696 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5616 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5840 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6008 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'inception_block_5x5', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.5628 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'inception_block_5x5', 'densenet_block_3x3', 'densenet_block_3x3']
# Episode: 27, Epsilon: 0.7861, Max Reward: 0.6008, Mean Reward: 0.5558, Accumulated Reward: 2.7788
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5584 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5456 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5812 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.5592 | Architecture: ['resnet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'vgg_block_5x5', 'densenet_block_5x5']
# Episode: 28, Epsilon: 0.7821, Max Reward: 0.5812, Mean Reward: 0.5533, Accumulated Reward: 2.7664
# Accuracy Reward: 0.3596 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5336 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5336 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5688 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.5984 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'vgg_block_5x5', 'resnet_block_3x3']
# Episode: 29, Epsilon: 0.7782, Max Reward: 0.5984, Mean Reward: 0.5188, Accumulated Reward: 2.5940
# Accuracy Reward: 0.5508 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5492 | Architecture: ['vgg_block_5x5', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5852 | Architecture: ['vgg_block_5x5', 'inception_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6304 | Architecture: ['vgg_block_5x5', 'inception_block_3x3', 'densenet_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6304 | Architecture: ['vgg_block_5x5', 'inception_block_3x3', 'densenet_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 30, Epsilon: 0.7743, Max Reward: 0.6304, Mean Reward: 0.5892, Accumulated Reward: 2.9460
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'resnet_block_5x5', 'no_op']
# Episode: 31, Epsilon: 0.7705, Max Reward: 0.5588, Mean Reward: 0.5367, Accumulated Reward: 2.6836
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5364 | Architecture: ['densenet_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5560 | Architecture: ['densenet_block_5x5', 'no_op', 'vgg_block_3x3', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5732 | Architecture: ['densenet_block_5x5', 'no_op', 'vgg_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5']
# Episode: 32, Epsilon: 0.7666, Max Reward: 0.5732, Mean Reward: 0.5283, Accumulated Reward: 2.6416
# Accuracy Reward: 0.3596 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5336 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5548 | Architecture: ['no_op', 'resnet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5788 | Architecture: ['no_op', 'resnet_block_3x3', 'vgg_block_5x5', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.5788 | Architecture: ['no_op', 'resnet_block_3x3', 'vgg_block_5x5', 'densenet_block_3x3', 'no_op']
# Episode: 33, Epsilon: 0.7628, Max Reward: 0.5788, Mean Reward: 0.5211, Accumulated Reward: 2.6056
# Accuracy Reward: 0.5112 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5416 | Architecture: ['inception_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5416 | Architecture: ['inception_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6132 | Architecture: ['inception_block_5x5', 'vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6044 | Architecture: ['inception_block_5x5', 'vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'vgg_block_3x3']
# Episode: 34, Epsilon: 0.7590, Max Reward: 0.6132, Mean Reward: 0.5624, Accumulated Reward: 2.8120
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5744 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5832 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5832 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5832 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Episode: 35, Epsilon: 0.7552, Max Reward: 0.5832, Mean Reward: 0.5692, Accumulated Reward: 2.8460
# Accuracy Reward: 0.3596 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5336 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5684 | Architecture: ['no_op', 'resnet_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5560 | Architecture: ['no_op', 'resnet_block_3x3', 'densenet_block_5x5', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.6108 | Architecture: ['no_op', 'resnet_block_3x3', 'densenet_block_5x5', 'inception_block_3x3', 'vgg_block_5x5']
# Episode: 36, Epsilon: 0.7514, Max Reward: 0.6108, Mean Reward: 0.5257, Accumulated Reward: 2.6284
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5656 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5140 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'densenet_block_5x5', 'resnet_block_3x3', 'no_op']
# Accuracy Reward: 0.5140 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'densenet_block_5x5', 'resnet_block_3x3', 'no_op']
# Episode: 37, Epsilon: 0.7476, Max Reward: 0.5656, Mean Reward: 0.5349, Accumulated Reward: 2.6744
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5280 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5364 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'inception_block_5x5', 'inception_block_5x5']
# Episode: 38, Epsilon: 0.7439, Max Reward: 0.5588, Mean Reward: 0.5408, Accumulated Reward: 2.7040
# Accuracy Reward: 0.5320 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6504 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6504 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6504 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6784 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'resnet_block_3x3', 'no_op', 'vgg_block_3x3']
# Episode: 39, Epsilon: 0.7402, Max Reward: 0.6784, Mean Reward: 0.6323, Accumulated Reward: 3.1616
# Accuracy Reward: 0.5508 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5720 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5784 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5784 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5500 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'inception_block_5x5']
# Episode: 40, Epsilon: 0.7365, Max Reward: 0.5784, Mean Reward: 0.5659, Accumulated Reward: 2.8296
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5632 | Architecture: ['resnet_block_3x3', 'no_op', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5632 | Architecture: ['resnet_block_3x3', 'no_op', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5632 | Architecture: ['resnet_block_3x3', 'no_op', 'densenet_block_5x5', 'no_op', 'no_op']
# Episode: 41, Epsilon: 0.7328, Max Reward: 0.5632, Mean Reward: 0.5467, Accumulated Reward: 2.7336
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5228 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5704 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5688 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op']
# Accuracy Reward: 0.5688 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op']
# Episode: 42, Epsilon: 0.7291, Max Reward: 0.5704, Mean Reward: 0.5534, Accumulated Reward: 2.7668
# Accuracy Reward: 0.5320 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5864 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5864 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5844 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'no_op', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.5844 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'no_op', 'densenet_block_3x3', 'no_op']
# Episode: 43, Epsilon: 0.7255, Max Reward: 0.5864, Mean Reward: 0.5747, Accumulated Reward: 2.8736
# Accuracy Reward: 0.5320 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6504 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6720 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6616 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'densenet_block_3x3', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.6632 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'densenet_block_3x3', 'densenet_block_3x3', 'densenet_block_5x5']
# Episode: 44, Epsilon: 0.7219, Max Reward: 0.6720, Mean Reward: 0.6358, Accumulated Reward: 3.1792
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5404 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5404 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5404 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5404 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Episode: 45, Epsilon: 0.7183, Max Reward: 0.5404, Mean Reward: 0.5367, Accumulated Reward: 2.6836
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5440 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5564 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5684 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_5x5', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.5684 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_5x5', 'densenet_block_3x3', 'no_op']
# Episode: 46, Epsilon: 0.7147, Max Reward: 0.5684, Mean Reward: 0.5518, Accumulated Reward: 2.7592
# Accuracy Reward: 0.5112 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5192 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5192 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5192 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4704 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'densenet_block_3x3']
# Episode: 47, Epsilon: 0.7111, Max Reward: 0.5192, Mean Reward: 0.5078, Accumulated Reward: 2.5392
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5652 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5652 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5652 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5460 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op', 'vgg_block_5x5']
# Episode: 48, Epsilon: 0.7075, Max Reward: 0.5652, Mean Reward: 0.5555, Accumulated Reward: 2.7776
# Accuracy Reward: 0.5112 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5540 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5152 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.1212 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'densenet_block_3x3', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5248 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'densenet_block_3x3', 'densenet_block_5x5', 'vgg_block_5x5']
# Episode: 49, Epsilon: 0.7040, Max Reward: 0.5540, Mean Reward: 0.4453, Accumulated Reward: 2.2264
# Accuracy Reward: 0.5320 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5920 | Architecture: ['vgg_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6560 | Architecture: ['vgg_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6560 | Architecture: ['vgg_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6560 | Architecture: ['vgg_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Episode: 50, Epsilon: 0.7005, Max Reward: 0.6560, Mean Reward: 0.6184, Accumulated Reward: 3.0920
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5280 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5204 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'inception_block_5x5', 'resnet_block_3x3']
# Episode: 51, Epsilon: 0.6970, Max Reward: 0.5588, Mean Reward: 0.5376, Accumulated Reward: 2.6880
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5712 | Architecture: ['resnet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5712 | Architecture: ['resnet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6620 | Architecture: ['resnet_block_3x3', 'vgg_block_5x5', 'no_op', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6620 | Architecture: ['resnet_block_3x3', 'vgg_block_5x5', 'no_op', 'vgg_block_5x5', 'no_op']
# Episode: 52, Epsilon: 0.6935, Max Reward: 0.6620, Mean Reward: 0.5977, Accumulated Reward: 2.9884
# Accuracy Reward: 0.4696 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5616 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5840 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6824 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6572 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'densenet_block_3x3']
# Episode: 53, Epsilon: 0.6900, Max Reward: 0.6824, Mean Reward: 0.5910, Accumulated Reward: 2.9548
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5440 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5652 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5744 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.5744 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'resnet_block_5x5', 'no_op']
# Episode: 54, Epsilon: 0.6866, Max Reward: 0.5744, Mean Reward: 0.5560, Accumulated Reward: 2.7800
# Accuracy Reward: 0.5508 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5720 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5340 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6108 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'resnet_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6108 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'resnet_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 55, Epsilon: 0.6831, Max Reward: 0.6108, Mean Reward: 0.5757, Accumulated Reward: 2.8784
# Accuracy Reward: 0.5508 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5720 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5784 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5784 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5784 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Episode: 56, Epsilon: 0.6797, Max Reward: 0.5784, Mean Reward: 0.5716, Accumulated Reward: 2.8580
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5440 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5124 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5124 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5468 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'inception_block_5x5', 'no_op', 'inception_block_3x3']
# Episode: 57, Epsilon: 0.6763, Max Reward: 0.5468, Mean Reward: 0.5275, Accumulated Reward: 2.6376
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4848 | Architecture: ['resnet_block_5x5', 'no_op', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5132 | Architecture: ['resnet_block_5x5', 'no_op', 'resnet_block_5x5', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5024 | Architecture: ['resnet_block_5x5', 'no_op', 'resnet_block_5x5', 'densenet_block_5x5', 'inception_block_5x5']
# Episode: 58, Epsilon: 0.6729, Max Reward: 0.5360, Mean Reward: 0.5145, Accumulated Reward: 2.5724
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5228 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5704 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6312 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6312 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op']
# Episode: 59, Epsilon: 0.6696, Max Reward: 0.6312, Mean Reward: 0.5783, Accumulated Reward: 2.8916
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5744 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5832 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5832 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6028 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'densenet_block_5x5']
# Episode: 60, Epsilon: 0.6662, Max Reward: 0.6028, Mean Reward: 0.5731, Accumulated Reward: 2.8656
# Accuracy Reward: 0.4696 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5728 | Architecture: ['densenet_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5344 | Architecture: ['densenet_block_3x3', 'inception_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5744 | Architecture: ['densenet_block_3x3', 'inception_block_3x3', 'densenet_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.5844 | Architecture: ['densenet_block_3x3', 'inception_block_3x3', 'densenet_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3']
# Episode: 61, Epsilon: 0.6629, Max Reward: 0.5844, Mean Reward: 0.5471, Accumulated Reward: 2.7356
# Accuracy Reward: 0.3596 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5508 | Architecture: ['no_op', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5508 | Architecture: ['no_op', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5820 | Architecture: ['no_op', 'vgg_block_3x3', 'no_op', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5888 | Architecture: ['no_op', 'vgg_block_3x3', 'no_op', 'inception_block_5x5', 'inception_block_5x5']
# Episode: 62, Epsilon: 0.6596, Max Reward: 0.5888, Mean Reward: 0.5264, Accumulated Reward: 2.6320
# Accuracy Reward: 0.5112 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5540 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5624 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5624 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op']
# Accuracy Reward: 0.5624 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op']
# Episode: 63, Epsilon: 0.6563, Max Reward: 0.5624, Mean Reward: 0.5505, Accumulated Reward: 2.7524
# Accuracy Reward: 0.4880 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5280 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6272 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6556 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6612 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'vgg_block_3x3', 'resnet_block_3x3']
# Episode: 64, Epsilon: 0.6530, Max Reward: 0.6612, Mean Reward: 0.5920, Accumulated Reward: 2.9600
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5376 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.5312 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'inception_block_3x3', 'inception_block_5x5']
# Episode: 65, Epsilon: 0.6497, Max Reward: 0.5588, Mean Reward: 0.5417, Accumulated Reward: 2.7084
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5376 | Architecture: ['resnet_block_3x3', 'no_op', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5500 | Architecture: ['resnet_block_3x3', 'no_op', 'densenet_block_3x3', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5500 | Architecture: ['resnet_block_3x3', 'no_op', 'densenet_block_3x3', 'densenet_block_5x5', 'no_op']
# Episode: 66, Epsilon: 0.6465, Max Reward: 0.5500, Mean Reward: 0.5363, Accumulated Reward: 2.6816
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5472 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5332 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'inception_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5184 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'inception_block_5x5', 'inception_block_5x5', 'resnet_block_5x5']
# Episode: 67, Epsilon: 0.6433, Max Reward: 0.5588, Mean Reward: 0.5359, Accumulated Reward: 2.6796
# Accuracy Reward: 0.4696 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5616 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5776 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5736 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'inception_block_3x3', 'resnet_block_3x3', 'no_op']
# Accuracy Reward: 0.5776 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'inception_block_3x3', 'resnet_block_3x3', 'densenet_block_3x3']
# Episode: 68, Epsilon: 0.6400, Max Reward: 0.5776, Mean Reward: 0.5520, Accumulated Reward: 2.7600
# Accuracy Reward: 0.5508 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5516 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5720 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5720 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5696 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'inception_block_5x5', 'no_op', 'resnet_block_3x3']
# Episode: 69, Epsilon: 0.6368, Max Reward: 0.5720, Mean Reward: 0.5632, Accumulated Reward: 2.8160
# Accuracy Reward: 0.5508 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5516 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5720 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5820 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'inception_block_5x5', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5820 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'inception_block_5x5', 'densenet_block_5x5', 'no_op']
# Episode: 70, Epsilon: 0.6337, Max Reward: 0.5820, Mean Reward: 0.5677, Accumulated Reward: 2.8384
# Accuracy Reward: 0.4696 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4920 | Architecture: ['densenet_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4920 | Architecture: ['densenet_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['densenet_block_3x3', 'densenet_block_5x5', 'no_op', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['densenet_block_3x3', 'densenet_block_5x5', 'no_op', 'resnet_block_5x5', 'no_op']
# Episode: 71, Epsilon: 0.6305, Max Reward: 0.5244, Mean Reward: 0.5005, Accumulated Reward: 2.5024
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5228 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# ...
# Episode: 975, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 976, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 977, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 978, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 979, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 980, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 981, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 982, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 983, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 984, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 985, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 986, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 987, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 988, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 989, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 990, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 991, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 992, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 993, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 994, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 995, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 996, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 997, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 998, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 999, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 1000, Epsilon: 0.0100, Max Reward: 0.5588, Mean Reward: 0.5514, Accumulated Reward: 2.7572

# %%
def plot_q_table(q_table, functions):
    states = list(q_table.keys())
    if not states:
        print("No Q-table entries.")
        return
    q_matrix = np.array([q_table[state] for state in states])
    state_labels = [str(state) for state in states]
    plt.figure(figsize=(max(8, len(functions)), min(20, len(states) // 2 + 4)))
    sns.heatmap(q_matrix, annot=False, fmt=".2f", cmap="coolwarm", xticklabels=functions, yticklabels=state_labels)
    plt.title("Q-Table (Single Agent)")
    plt.xlabel("Actions")
    plt.ylabel("States (Architectures)")
    plt.tight_layout()
    plt.show()

plot_q_table(q_table, functions)

# %%
best_layers = []
state = tuple(env.reset())
done = False
current_layer = 0

while not done:
    if state not in q_table:
        q_table[state] = np.zeros(len(functions))
    action = np.argmax(q_table[state])
    best_layers.append(action)
    state, reward_acc, done, current_layer = env.step(action)
    state = tuple(state)

print("Best architecture found:")
print(f"Acc: {reward_acc}")
print(f"Layers: {[functions[i] for i in best_layers]}")
print(f"Layers: {best_layers}")
# Out:
# Best architecture found:
# Acc: 0.5587999820709229
# Layers: ['resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Layers: [3, 7, 0, 0, 0]

# %%
layers_selected = [functions[i] for i in best_layers]

# %%
# Construct the best CNN model using the selected layers
model = build_cnn(layers_selected, input_shape, num_classes)

# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=retrain_patience, 
    restore_best_weights=True
)

# Retrain the model
history = model.fit(
    train_data, 
    train_labels, 
    validation_data=(val_data, val_labels), 
    epochs=retrain_epochs, 
    batch_size=batch_size, 
    callbacks=[early_stopping], 
    verbose=1
)
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 13s 9ms/step - loss: 2.4086 - accuracy: 0.5023 - val_loss: 1.1531 - val_accuracy: 0.6052
# Epoch 2/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.9456 - accuracy: 0.6730 - val_loss: 1.2474 - val_accuracy: 0.5707
# Epoch 3/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.7424 - accuracy: 0.7453 - val_loss: 1.1202 - val_accuracy: 0.6300
# Epoch 4/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.5513 - accuracy: 0.8110 - val_loss: 1.1250 - val_accuracy: 0.6562
# Epoch 5/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.3788 - accuracy: 0.8687 - val_loss: 1.3279 - val_accuracy: 0.6471
# Epoch 6/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.2768 - accuracy: 0.9043 - val_loss: 1.5858 - val_accuracy: 0.6386
# Epoch 7/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.1869 - accuracy: 0.9351 - val_loss: 1.8840 - val_accuracy: 0.6061
# Epoch 8/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.1668 - accuracy: 0.9413 - val_loss: 1.8495 - val_accuracy: 0.6307
# Epoch 9/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.1238 - accuracy: 0.9573 - val_loss: 1.9528 - val_accuracy: 0.6338
# Epoch 10/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.1036 - accuracy: 0.9643 - val_loss: 2.1735 - val_accuracy: 0.6315
# Epoch 11/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.0977 - accuracy: 0.9664 - val_loss: 2.6447 - val_accuracy: 0.5986
# Epoch 12/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.0819 - accuracy: 0.9731 - val_loss: 2.5568 - val_accuracy: 0.6299
# Epoch 13/200
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.0812 - accuracy: 0.9723 - val_loss: 2.2827 - val_accuracy: 0.6479

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()

# %%
# Print final results
print("Final Results:")
print(f"Best Validation Accuracy: {max(history.history['val_accuracy']):.4f}")
print(f"Best Training Accuracy: {max(history.history['accuracy']):.4f}")
print(f"Final Validation Loss: {min(history.history['val_loss']):.4f}")
print(f"Final Training Loss: {min(history.history['loss']):.4f}")
# Out:
# Final Results:
# Best Validation Accuracy: 0.6562
# Best Training Accuracy: 0.9731
# Final Validation Loss: 1.1202
# Final Training Loss: 0.0812

# %%
test_loss, test_accuracy = model.evaluate(input_test, label_test, verbose=1)

# Print test results
print("Test Results:")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.1244 - accuracy: 0.6226
# Test Results:
# Test Accuracy: 0.6226
# Test Loss: 1.1244

# %%
# Get predictions for the test set
predictions = model.predict(input_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(label_test, axis=1)

# Calculate accuracy per class
num_classes = label_test.shape[1]
class_accuracies = []
for class_idx in range(num_classes):
    class_mask = (true_classes == class_idx)
    class_accuracy = np.mean(predicted_classes[class_mask] == true_classes[class_mask])
    class_accuracies.append(class_accuracy)


class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']


# Plot the accuracy per class
plt.figure(figsize=(10, 6))
plt.bar(range(num_classes), class_accuracies, color='skyblue')
plt.xlabel('Class')
plt.ylabel('Accuracy')
plt.title('Accuracy per Class')
plt.xticks(range(num_classes), class_names, rotation=45)  # Add class names and rotate for better readability
plt.ylim(0, 1)
plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step
