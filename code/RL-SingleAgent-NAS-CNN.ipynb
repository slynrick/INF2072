# %%
# Import necessary libraries
import tensorflow as tf
from keras import layers, models, optimizers
from keras.datasets import cifar10
from keras.utils import to_categorical
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.model_selection import train_test_split

# %%
# Set random seeds for reproducibility
np.random.seed(int(time.time()))
random.seed(int(time.time()))
tf.random.set_seed(int(time.time()))

# %%
# Load CIFAR-10 dataset
(input_train, label_train), (input_test, label_test) = cifar10.load_data()
input_train, input_test = input_train / 255.0, input_test / 255.0  # Normalize to [0, 1]
label_train, label_test = to_categorical(label_train), to_categorical(label_test)

# Split training data into training and validation sets
train_data, val_data, train_labels, val_labels = train_test_split(
    input_train, label_train, test_size=0.2, stratify=label_train, random_state=random.randint(0, 1000)
)

# %%
print(train_data.shape)
print(val_data.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def sample_subset(data, labels, num_samples_per_class):
    sampled_data = []
    sampled_labels = []
    for class_idx in range(labels.shape[1]):  # Iterate over each class
        class_mask = labels[:, class_idx] == 1  # Find samples of the current class
        class_data = data[class_mask]
        class_labels = labels[class_mask]
        
        # Randomly sample the specified number of samples
        indices = np.random.choice(len(class_data), num_samples_per_class, replace=False)
        sampled_data.append(class_data[indices])
        sampled_labels.append(class_labels[indices])
    
    # Concatenate all sampled data and labels
    return np.concatenate(sampled_data), np.concatenate(sampled_labels)

# %%
# Hiperparâmetros
num_layers = 5  # Número de camadas ocultas
alpha = 0.1  # Learning rate
gamma = 0.9  # Discount factor
epsilon = 0.9  # Initial exploration rate
epsilon_decay = 0.995
min_epsilon = 0.01
num_episodes = 1000  # Número de episódios para treinar o agente

input_channels = 3  # For RGB images
num_classes = 10  # Example for CIFAR-10
batch_size = 32
input_shape = (batch_size, 32, 32, 3,)

patience = 5
rl_epochs = 30  # Número de épocas para treinar a rede com os dados da memória
retrain_patience = 10
retrain_epochs = 200  # Número de épocas para treinar a rede com os dados da memória

# %%
functions = [
    'no_op',
    'vgg_block_3x3', 'vgg_block_5x5',
    'resnet_block_3x3', 'resnet_block_5x5',
    'inception_block_3x3', 'inception_block_5x5',
    'densenet_block_3x3', 'densenet_block_5x5'
]
functions_size = len(functions)

# %%
# Define block implementations
def vgg_block(input_tensor, filters, kernel_size, layer_name):
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='relu', name=f"{layer_name}_1")(input_tensor)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_1")(x)  # Add Batch Normalization
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='relu', name=f"{layer_name}_2")(x)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_2")(x)  # Add Batch Normalization
    x = layers.MaxPooling2D(pool_size=(2, 2), name=f"{layer_name}_3")(x)
    return x

def resnet_block(input_tensor, filters, kernel_size, layer_name):
    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), padding='same', name=f"{layer_name}_1")(input_tensor)
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='relu', name=f"{layer_name}_2")(input_tensor)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_1")(x)  # Add Batch Normalization
    x = layers.Conv2D(filters, kernel_size, padding='same', name=f"{layer_name}_3")(x)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_2")(x)  # Add Batch Normalization
    x = layers.Add(name=f"{layer_name}_4")([x, shortcut])
    x = layers.Activation('relu', name=f"{layer_name}_5")(x)
    return x

def inception_block(input_tensor, kernel_size, layer_name):
    branch1 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_1")(input_tensor)
    branch2 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_2")(input_tensor)
    branch2 = layers.Conv2D(64, kernel_size, padding='same', activation='relu', name=f"{layer_name}_3")(branch2)
    branch3 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_4")(input_tensor)
    branch3 = layers.Conv2D(64, kernel_size=(kernel_size[0] + 2, kernel_size[1] + 2), padding='same', activation='relu', name=f"{layer_name}_5")(branch3)
    branch4 = layers.MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same', name=f"{layer_name}_6")(input_tensor)
    branch4 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_7")(branch4)
    return layers.Concatenate(name=f"{layer_name}_8")([branch1, branch2, branch3, branch4])

def densenet_block(input_tensor, filters, kernel_size, layer_name):
    x = layers.Conv2D(filters, kernel_size, padding='same', name=f"{layer_name}_1")(input_tensor)
    x = layers.BatchNormalization(name=f"{layer_name}_2")(x)
    x = layers.ReLU(name=f"{layer_name}_3")(x)
    return layers.Concatenate(name=f"{layer_name}_4")([input_tensor, x])

# Define CNN model
def build_cnn(layers_config, input_shape, num_classes):
    input_tensor = layers.Input(shape=input_shape[1:], name="input")
    x = input_tensor
    for idx, layer in enumerate(layers_config):
        if layer == 'vgg_block_3x3':
            x = vgg_block(x, 64, (3, 3), layer_name=f"vgg_block_3x3_{idx}")
        elif layer == 'vgg_block_5x5':
            x = vgg_block(x, 64, (5, 5), layer_name=f"vgg_block_5x5_{idx}")
        elif layer == 'resnet_block_3x3':
            x = resnet_block(x, 64, (3, 3), layer_name=f"resnet_block_3x3_{idx}")
        elif layer == 'resnet_block_5x5':
            x = resnet_block(x, 64, (5, 5), layer_name=f"resnet_block_5x5_{idx}")
        elif layer == 'inception_block_3x3':
            x = inception_block(x, (3, 3), layer_name=f"inception_block_3x3_{idx}")
        elif layer == 'inception_block_5x5':
            x = inception_block(x, (5, 5), layer_name=f"inception_block_5x5_{idx}")
        elif layer == 'densenet_block_3x3':
            x = densenet_block(x, 32, (3, 3), layer_name=f"densenet_block_3x3_{idx}")
        elif layer == 'densenet_block_5x5':
            x = densenet_block(x, 32, (5, 5), layer_name=f"densenet_block_5x5_{idx}")
        elif layer == 'no_op':
            x = layers.Lambda(lambda y: y, name=f"ide_{idx}")(x)
    x = layers.Flatten(name="flatten")(x)
    output_tensor = layers.Dense(num_classes, activation='softmax', name="output")(x)
    model = models.Model(inputs=[input_tensor], outputs=[output_tensor], name='cnn_model')
    model.compile(optimizer=optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
class CNNEnv:
    def __init__(self, input_shape, num_classes, num_layers):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.layers_str = ['no_op'] * num_layers
        self.current_layer_index = 0
        self.evaluation_cache = {}

    def reset(self):
        self.layers_str = ['no_op'] * self.num_layers
        self.current_layer_index = 0
        return self.get_state()

    def step(self, action):
        self.layers_str[self.current_layer_index] = functions[action]
        next_state = self.get_state()
        layers_tuple = tuple(self.layers_str)
        if layers_tuple in self.evaluation_cache:
            reward = self.evaluation_cache[layers_tuple]
        else:
            reward = self.evaluate()
            self.evaluation_cache[layers_tuple] = reward
        self.current_layer_index += 1
        done = self.current_layer_index >= self.num_layers
        return next_state, reward, done, self.current_layer_index

    def get_state(self):
        return self.layers_str

    def evaluate(self):

        # Sample 1000 random samples per class for training
        subsample_train_data, subsample_train_labels = sample_subset(train_data, train_labels, 1000)

        # Sample 250 random samples per class for validation
        subsample_val_data, subsample_val_labels = sample_subset(val_data, val_labels, 250)

        model = build_cnn(self.layers_str, self.input_shape, self.num_classes)
        
        # Early stopping callback
        early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='val_loss', 
            patience=retrain_patience, 
            restore_best_weights=True
        )
        
        history = model.fit(
            subsample_train_data, 
            subsample_train_labels,
            validation_data=(subsample_val_data, subsample_val_labels), 
            callbacks=[early_stopping],
            epochs=rl_epochs, 
            batch_size=batch_size, 
            verbose=0
        )
        
        val_accuracy = max(history.history['val_accuracy'])
        return val_accuracy

# %%
# Initialize the environment
env = CNNEnv(input_shape, num_classes, num_layers)

# Initialize Q-table for the single agent
q_table = np.zeros((num_layers, len(functions)))

# RL
for episode in range(num_episodes):
    state = env.reset()
    done = False
    current_layer = 0

    all_rewards = []
    while not done:
        # Choose an action using epsilon-greedy policy
        if random.random() > epsilon:
            # Exploit: Choose the best action
            action = np.argmax(q_table[current_layer])
        else:
            # Explore: Choose a random action
            action = random.randint(0, len(functions) - 1)

        # Take the action and observe the next state and reward
        next_state, reward_acc, done, next_layer = env.step(action)

        print(f"Accuracy Reward: {reward_acc:.4f} | Architecture: {env.layers_str}")

        reward = reward_acc  # Use accuracy as the primary reward

        all_rewards.append(reward)

        # Update the Q-table
        if next_layer < num_layers:  # Ensure next_layer is within bounds
            q_table[current_layer, action] += alpha * (
                reward + gamma * np.max(q_table[next_layer]) * (1 - done) - q_table[current_layer, action]
            )

        # Move to the next state
        state = next_state
        current_layer = next_layer

    # Decay epsilon
    epsilon = max(min_epsilon, epsilon * epsilon_decay)

    # Log episode results
    print(f"Episode: {episode + 1}, Epsilon: {epsilon:.4f}, Max Reward: {np.max(all_rewards):.4f}, Mean Reward: {np.mean(all_rewards):.4f}, Accumulated Reward: {np.sum(all_rewards):.4f}")
# Out:
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5504 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'vgg_block_5x5']
# Episode: 1, Epsilon: 0.8955, Max Reward: 0.5504, Mean Reward: 0.5213, Accumulated Reward: 2.6064
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5176 | Architecture: ['inception_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5364 | Architecture: ['inception_block_3x3', 'densenet_block_3x3', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5364 | Architecture: ['inception_block_3x3', 'densenet_block_3x3', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.4964 | Architecture: ['inception_block_3x3', 'densenet_block_3x3', 'inception_block_3x3', 'no_op', 'resnet_block_5x5']
# Episode: 2, Epsilon: 0.8910, Max Reward: 0.5364, Mean Reward: 0.5202, Accumulated Reward: 2.6008
# Accuracy Reward: 0.4484 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5620 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5916 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5716 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5924 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'resnet_block_5x5', 'inception_block_5x5', 'inception_block_5x5']
# Episode: 3, Epsilon: 0.8866, Max Reward: 0.5924, Mean Reward: 0.5532, Accumulated Reward: 2.7660
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5148 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5008 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5072 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'resnet_block_3x3', 'no_op']
# Accuracy Reward: 0.5072 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'resnet_block_3x3', 'no_op']
# Episode: 4, Epsilon: 0.8821, Max Reward: 0.5352, Mean Reward: 0.5130, Accumulated Reward: 2.5652
# Accuracy Reward: 0.4584 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5292 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5484 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5484 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6420 | Architecture: ['densenet_block_5x5', 'vgg_block_3x3', 'inception_block_5x5', 'no_op', 'vgg_block_3x3']
# Episode: 5, Epsilon: 0.8777, Max Reward: 0.6420, Mean Reward: 0.5453, Accumulated Reward: 2.7264
# Accuracy Reward: 0.5160 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5160 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5592 | Architecture: ['inception_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5540 | Architecture: ['inception_block_5x5', 'no_op', 'vgg_block_3x3', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5540 | Architecture: ['inception_block_5x5', 'no_op', 'vgg_block_3x3', 'densenet_block_5x5', 'no_op']
# Episode: 6, Epsilon: 0.8733, Max Reward: 0.5592, Mean Reward: 0.5398, Accumulated Reward: 2.6992
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5548 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6168 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6684 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6540 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'vgg_block_5x5', 'resnet_block_3x3']
# Episode: 7, Epsilon: 0.8690, Max Reward: 0.6684, Mean Reward: 0.6058, Accumulated Reward: 3.0292
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5412 | Architecture: ['inception_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5044 | Architecture: ['inception_block_3x3', 'densenet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.4652 | Architecture: ['inception_block_3x3', 'densenet_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.4892 | Architecture: ['inception_block_3x3', 'densenet_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'resnet_block_5x5']
# Episode: 8, Epsilon: 0.8646, Max Reward: 0.5412, Mean Reward: 0.5028, Accumulated Reward: 2.5140
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5412 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5716 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5716 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'vgg_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 9, Epsilon: 0.8603, Max Reward: 0.5716, Mean Reward: 0.5457, Accumulated Reward: 2.7284
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5320 | Architecture: ['no_op', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5056 | Architecture: ['no_op', 'resnet_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4988 | Architecture: ['no_op', 'resnet_block_5x5', 'resnet_block_5x5', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.4988 | Architecture: ['no_op', 'resnet_block_5x5', 'resnet_block_5x5', 'inception_block_3x3', 'no_op']
# Episode: 10, Epsilon: 0.8560, Max Reward: 0.5320, Mean Reward: 0.4770, Accumulated Reward: 2.3848
# Accuracy Reward: 0.5468 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5348 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5260 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5532 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.5420 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_3x3', 'resnet_block_5x5']
# Episode: 11, Epsilon: 0.8517, Max Reward: 0.5532, Mean Reward: 0.5406, Accumulated Reward: 2.7028
# Accuracy Reward: 0.5680 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5856 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6156 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6048 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'densenet_block_5x5', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.6272 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'densenet_block_5x5', 'resnet_block_5x5', 'inception_block_5x5']
# Episode: 12, Epsilon: 0.8475, Max Reward: 0.6272, Mean Reward: 0.6002, Accumulated Reward: 3.0012
# Accuracy Reward: 0.5160 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5004 | Architecture: ['inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5300 | Architecture: ['inception_block_5x5', 'resnet_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5300 | Architecture: ['inception_block_5x5', 'resnet_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5420 | Architecture: ['inception_block_5x5', 'resnet_block_5x5', 'vgg_block_5x5', 'no_op', 'inception_block_3x3']
# Episode: 13, Epsilon: 0.8432, Max Reward: 0.5420, Mean Reward: 0.5237, Accumulated Reward: 2.6184
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.3672 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'densenet_block_3x3']
# Episode: 14, Epsilon: 0.8390, Max Reward: 0.5352, Mean Reward: 0.4685, Accumulated Reward: 2.3424
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5596 | Architecture: ['resnet_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5440 | Architecture: ['resnet_block_5x5', 'vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5440 | Architecture: ['resnet_block_5x5', 'vgg_block_5x5', 'densenet_block_3x3', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.6296 | Architecture: ['resnet_block_5x5', 'vgg_block_5x5', 'densenet_block_3x3', 'inception_block_5x5', 'vgg_block_3x3']
# Episode: 15, Epsilon: 0.8348, Max Reward: 0.6296, Mean Reward: 0.5625, Accumulated Reward: 2.8124
# Accuracy Reward: 0.5160 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4764 | Architecture: ['inception_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5016 | Architecture: ['inception_block_5x5', 'densenet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5044 | Architecture: ['inception_block_5x5', 'densenet_block_3x3', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.4976 | Architecture: ['inception_block_5x5', 'densenet_block_3x3', 'resnet_block_5x5', 'inception_block_5x5', 'resnet_block_3x3']
# Episode: 16, Epsilon: 0.8306, Max Reward: 0.5160, Mean Reward: 0.4992, Accumulated Reward: 2.4960
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4900 | Architecture: ['no_op', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5208 | Architecture: ['no_op', 'inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6160 | Architecture: ['no_op', 'inception_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6284 | Architecture: ['no_op', 'inception_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'densenet_block_5x5']
# Episode: 17, Epsilon: 0.8265, Max Reward: 0.6284, Mean Reward: 0.5210, Accumulated Reward: 2.6048
# Accuracy Reward: 0.5680 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5856 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5848 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6108 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'inception_block_5x5', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.6156 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'inception_block_5x5', 'inception_block_3x3', 'densenet_block_3x3']
# Episode: 18, Epsilon: 0.8224, Max Reward: 0.6156, Mean Reward: 0.5930, Accumulated Reward: 2.9648
# Accuracy Reward: 0.5468 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5468 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5276 | Architecture: ['resnet_block_3x3', 'no_op', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5276 | Architecture: ['resnet_block_3x3', 'no_op', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5272 | Architecture: ['resnet_block_3x3', 'no_op', 'inception_block_3x3', 'no_op', 'inception_block_3x3']
# Episode: 19, Epsilon: 0.8182, Max Reward: 0.5468, Mean Reward: 0.5352, Accumulated Reward: 2.6760
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5228 | Architecture: ['no_op', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5008 | Architecture: ['no_op', 'inception_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5008 | Architecture: ['no_op', 'inception_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5008 | Architecture: ['no_op', 'inception_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Episode: 20, Epsilon: 0.8141, Max Reward: 0.5228, Mean Reward: 0.4750, Accumulated Reward: 2.3748
# Accuracy Reward: 0.5480 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5480 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5536 | Architecture: ['vgg_block_5x5', 'no_op', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5812 | Architecture: ['vgg_block_5x5', 'no_op', 'resnet_block_5x5', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.6256 | Architecture: ['vgg_block_5x5', 'no_op', 'resnet_block_5x5', 'densenet_block_5x5', 'vgg_block_5x5']
# Episode: 21, Epsilon: 0.8101, Max Reward: 0.6256, Mean Reward: 0.5713, Accumulated Reward: 2.8564
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5148 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4796 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4784 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.4888 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'resnet_block_5x5', 'densenet_block_3x3', 'inception_block_3x3']
# Episode: 22, Epsilon: 0.8060, Max Reward: 0.5352, Mean Reward: 0.4994, Accumulated Reward: 2.4968
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4900 | Architecture: ['no_op', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4908 | Architecture: ['no_op', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4908 | Architecture: ['no_op', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4908 | Architecture: ['no_op', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Episode: 23, Epsilon: 0.8020, Max Reward: 0.4908, Mean Reward: 0.4624, Accumulated Reward: 2.3120
# Accuracy Reward: 0.5468 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5608 | Architecture: ['resnet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5972 | Architecture: ['resnet_block_3x3', 'vgg_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5804 | Architecture: ['resnet_block_3x3', 'vgg_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5752 | Architecture: ['resnet_block_3x3', 'vgg_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'densenet_block_3x3']
# Episode: 24, Epsilon: 0.7980, Max Reward: 0.5972, Mean Reward: 0.5721, Accumulated Reward: 2.8604
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5148 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5008 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5016 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.5780 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'densenet_block_3x3', 'inception_block_3x3', 'vgg_block_5x5']
# Episode: 25, Epsilon: 0.7940, Max Reward: 0.5780, Mean Reward: 0.5261, Accumulated Reward: 2.6304
# Accuracy Reward: 0.5480 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5480 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5616 | Architecture: ['vgg_block_5x5', 'no_op', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5460 | Architecture: ['vgg_block_5x5', 'no_op', 'resnet_block_3x3', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5632 | Architecture: ['vgg_block_5x5', 'no_op', 'resnet_block_3x3', 'inception_block_5x5', 'inception_block_3x3']
# Episode: 26, Epsilon: 0.7900, Max Reward: 0.5632, Mean Reward: 0.5534, Accumulated Reward: 2.7668
# Accuracy Reward: 0.5160 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5388 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4808 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5252 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.5252 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op']
# Episode: 27, Epsilon: 0.7861, Max Reward: 0.5388, Mean Reward: 0.5172, Accumulated Reward: 2.5860
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5472 | Architecture: ['no_op', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6244 | Architecture: ['no_op', 'vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6260 | Architecture: ['no_op', 'vgg_block_5x5', 'vgg_block_3x3', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.6448 | Architecture: ['no_op', 'vgg_block_5x5', 'vgg_block_3x3', 'densenet_block_5x5', 'vgg_block_5x5']
# Episode: 28, Epsilon: 0.7821, Max Reward: 0.6448, Mean Reward: 0.5584, Accumulated Reward: 2.7920
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4744 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.4744 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.4744 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op']
# Episode: 29, Epsilon: 0.7782, Max Reward: 0.5352, Mean Reward: 0.4934, Accumulated Reward: 2.4672
# Accuracy Reward: 0.5480 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5724 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6292 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6252 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.6252 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'densenet_block_5x5', 'no_op']
# Episode: 30, Epsilon: 0.7743, Max Reward: 0.6292, Mean Reward: 0.6000, Accumulated Reward: 3.0000
# Accuracy Reward: 0.4584 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5184 | Architecture: ['densenet_block_5x5', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4788 | Architecture: ['densenet_block_5x5', 'inception_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4788 | Architecture: ['densenet_block_5x5', 'inception_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4788 | Architecture: ['densenet_block_5x5', 'inception_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Episode: 31, Epsilon: 0.7705, Max Reward: 0.5184, Mean Reward: 0.4826, Accumulated Reward: 2.4132
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.2476 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5076 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'densenet_block_5x5', 'inception_block_5x5']
# Episode: 32, Epsilon: 0.7666, Max Reward: 0.5352, Mean Reward: 0.4530, Accumulated Reward: 2.2648
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5472 | Architecture: ['no_op', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5532 | Architecture: ['no_op', 'vgg_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5532 | Architecture: ['no_op', 'vgg_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5396 | Architecture: ['no_op', 'vgg_block_5x5', 'resnet_block_3x3', 'no_op', 'densenet_block_3x3']
# Episode: 33, Epsilon: 0.7628, Max Reward: 0.5532, Mean Reward: 0.5086, Accumulated Reward: 2.5428
# Accuracy Reward: 0.5160 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5388 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5404 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5468 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'inception_block_3x3', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.4908 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'inception_block_3x3', 'densenet_block_3x3', 'resnet_block_5x5']
# Episode: 34, Epsilon: 0.7590, Max Reward: 0.5468, Mean Reward: 0.5266, Accumulated Reward: 2.6328
# Accuracy Reward: 0.5160 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5160 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5004 | Architecture: ['inception_block_5x5', 'no_op', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5028 | Architecture: ['inception_block_5x5', 'no_op', 'resnet_block_5x5', 'resnet_block_3x3', 'no_op']
# Accuracy Reward: 0.4744 | Architecture: ['inception_block_5x5', 'no_op', 'resnet_block_5x5', 'resnet_block_3x3', 'resnet_block_3x3']
# Episode: 35, Epsilon: 0.7552, Max Reward: 0.5160, Mean Reward: 0.5019, Accumulated Reward: 2.5096
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5200 | Architecture: ['inception_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5464 | Architecture: ['inception_block_3x3', 'vgg_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5384 | Architecture: ['inception_block_3x3', 'vgg_block_5x5', 'resnet_block_5x5', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.5384 | Architecture: ['inception_block_3x3', 'vgg_block_5x5', 'resnet_block_5x5', 'inception_block_3x3', 'no_op']
# Episode: 36, Epsilon: 0.7514, Max Reward: 0.5464, Mean Reward: 0.5314, Accumulated Reward: 2.6572
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5452 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4840 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5028 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'inception_block_3x3', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.5188 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'inception_block_3x3', 'resnet_block_5x5', 'inception_block_3x3']
# Episode: 37, Epsilon: 0.7476, Max Reward: 0.5452, Mean Reward: 0.5172, Accumulated Reward: 2.5860
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5372 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5292 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5292 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5292 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'densenet_block_3x3', 'no_op', 'no_op']
# Episode: 38, Epsilon: 0.7439, Max Reward: 0.5372, Mean Reward: 0.5320, Accumulated Reward: 2.6600
# Accuracy Reward: 0.5468 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5080 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5060 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5060 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5060 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Episode: 39, Epsilon: 0.7402, Max Reward: 0.5468, Mean Reward: 0.5146, Accumulated Reward: 2.5728
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5452 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5252 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5344 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'vgg_block_5x5', 'resnet_block_3x3', 'no_op']
# Accuracy Reward: 0.5344 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'vgg_block_5x5', 'resnet_block_3x3', 'no_op']
# Episode: 40, Epsilon: 0.7365, Max Reward: 0.5452, Mean Reward: 0.5349, Accumulated Reward: 2.6744
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4776 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5776 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'inception_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.5776 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'inception_block_3x3', 'vgg_block_5x5', 'no_op']
# Episode: 41, Epsilon: 0.7328, Max Reward: 0.5776, Mean Reward: 0.5354, Accumulated Reward: 2.6768
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5136 | Architecture: ['resnet_block_5x5', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5588 | Architecture: ['resnet_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5816 | Architecture: ['resnet_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.6844 | Architecture: ['resnet_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'inception_block_5x5', 'vgg_block_5x5']
# Episode: 42, Epsilon: 0.7291, Max Reward: 0.6844, Mean Reward: 0.5747, Accumulated Reward: 2.8736
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5284 | Architecture: ['inception_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4940 | Architecture: ['inception_block_3x3', 'inception_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5480 | Architecture: ['inception_block_3x3', 'inception_block_5x5', 'densenet_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6044 | Architecture: ['inception_block_3x3', 'inception_block_5x5', 'densenet_block_3x3', 'vgg_block_3x3', 'densenet_block_3x3']
# Episode: 43, Epsilon: 0.7255, Max Reward: 0.6044, Mean Reward: 0.5378, Accumulated Reward: 2.6888
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5372 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5372 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5372 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'vgg_block_5x5']
# Episode: 44, Epsilon: 0.7219, Max Reward: 0.5372, Mean Reward: 0.5364, Accumulated Reward: 2.6820
# Accuracy Reward: 0.5680 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5680 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6516 | Architecture: ['vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6516 | Architecture: ['vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6680 | Architecture: ['vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op', 'densenet_block_3x3']
# Episode: 45, Epsilon: 0.7183, Max Reward: 0.6680, Mean Reward: 0.6214, Accumulated Reward: 3.1072
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5284 | Architecture: ['inception_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4920 | Architecture: ['inception_block_3x3', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.3516 | Architecture: ['inception_block_3x3', 'inception_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.5160 | Architecture: ['inception_block_3x3', 'inception_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'inception_block_3x3']
# Episode: 46, Epsilon: 0.7147, Max Reward: 0.5284, Mean Reward: 0.4804, Accumulated Reward: 2.4020
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4560 | Architecture: ['no_op', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5236 | Architecture: ['no_op', 'densenet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5236 | Architecture: ['no_op', 'densenet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5236 | Architecture: ['no_op', 'densenet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op']
# Episode: 47, Epsilon: 0.7111, Max Reward: 0.5236, Mean Reward: 0.4753, Accumulated Reward: 2.3764
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5448 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5044 | Architecture: ['no_op', 'resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5044 | Architecture: ['no_op', 'resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5676 | Architecture: ['no_op', 'resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'vgg_block_3x3']
# Episode: 48, Epsilon: 0.7075, Max Reward: 0.5676, Mean Reward: 0.4942, Accumulated Reward: 2.4708
# Accuracy Reward: 0.5160 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5388 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5336 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5336 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.1692 | Architecture: ['inception_block_5x5', 'inception_block_5x5', 'densenet_block_5x5', 'no_op', 'densenet_block_3x3']
# Episode: 49, Epsilon: 0.7040, Max Reward: 0.5388, Mean Reward: 0.4582, Accumulated Reward: 2.2912
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.1000 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.1000 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op']
# Episode: 50, Epsilon: 0.7005, Max Reward: 0.5352, Mean Reward: 0.3419, Accumulated Reward: 1.7096
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5140 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5316 | Architecture: ['inception_block_3x3', 'no_op', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5684 | Architecture: ['inception_block_3x3', 'no_op', 'densenet_block_5x5', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5376 | Architecture: ['inception_block_3x3', 'no_op', 'densenet_block_5x5', 'densenet_block_5x5', 'densenet_block_3x3']
# Episode: 51, Epsilon: 0.6970, Max Reward: 0.5684, Mean Reward: 0.5331, Accumulated Reward: 2.6656
# Accuracy Reward: 0.4484 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4960 | Architecture: ['densenet_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5456 | Architecture: ['densenet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5180 | Architecture: ['densenet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.5180 | Architecture: ['densenet_block_3x3', 'densenet_block_5x5', 'resnet_block_5x5', 'inception_block_3x3', 'no_op']
# Episode: 52, Epsilon: 0.6935, Max Reward: 0.5456, Mean Reward: 0.5052, Accumulated Reward: 2.5260
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5148 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4796 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4796 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4796 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Episode: 53, Epsilon: 0.6900, Max Reward: 0.5352, Mean Reward: 0.4978, Accumulated Reward: 2.4888
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5148 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5488 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5612 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'vgg_block_3x3', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.6460 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'vgg_block_3x3', 'resnet_block_5x5', 'vgg_block_5x5']
# Episode: 54, Epsilon: 0.6866, Max Reward: 0.6460, Mean Reward: 0.5612, Accumulated Reward: 2.8060
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5148 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5196 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4912 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'densenet_block_5x5', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.5292 | Architecture: ['resnet_block_5x5', 'resnet_block_3x3', 'densenet_block_5x5', 'densenet_block_3x3', 'vgg_block_3x3']
# Episode: 55, Epsilon: 0.6831, Max Reward: 0.5352, Mean Reward: 0.5180, Accumulated Reward: 2.5900
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4976 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.4944 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_3x3', 'densenet_block_3x3']
# Episode: 56, Epsilon: 0.6797, Max Reward: 0.5352, Mean Reward: 0.5003, Accumulated Reward: 2.5016
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5328 | Architecture: ['resnet_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6224 | Architecture: ['resnet_block_5x5', 'no_op', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6208 | Architecture: ['resnet_block_5x5', 'no_op', 'vgg_block_3x3', 'vgg_block_3x3', 'densenet_block_3x3']
# Episode: 57, Epsilon: 0.6763, Max Reward: 0.6224, Mean Reward: 0.5693, Accumulated Reward: 2.8464
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5580 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.5580 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'vgg_block_5x5', 'no_op']
# Episode: 58, Epsilon: 0.6729, Max Reward: 0.5580, Mean Reward: 0.5443, Accumulated Reward: 2.7216
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5452 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4904 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4904 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4812 | Architecture: ['resnet_block_5x5', 'densenet_block_5x5', 'resnet_block_5x5', 'no_op', 'resnet_block_5x5']
# Episode: 59, Epsilon: 0.6696, Max Reward: 0.5452, Mean Reward: 0.5085, Accumulated Reward: 2.5424
# Accuracy Reward: 0.5468 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5080 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5060 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5060 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5292 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'inception_block_3x3']
# Episode: 60, Epsilon: 0.6662, Max Reward: 0.5468, Mean Reward: 0.5192, Accumulated Reward: 2.5960
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5228 | Architecture: ['no_op', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5008 | Architecture: ['no_op', 'inception_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5008 | Architecture: ['no_op', 'inception_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5008 | Architecture: ['no_op', 'inception_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Episode: 61, Epsilon: 0.6629, Max Reward: 0.5228, Mean Reward: 0.4750, Accumulated Reward: 2.3748
# Accuracy Reward: 0.5480 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5716 | Architecture: ['vgg_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5616 | Architecture: ['vgg_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5556 | Architecture: ['vgg_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5820 | Architecture: ['vgg_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'densenet_block_5x5', 'resnet_block_3x3']
# Episode: 62, Epsilon: 0.6596, Max Reward: 0.5820, Mean Reward: 0.5638, Accumulated Reward: 2.8188
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5396 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.5564 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'inception_block_3x3']
# Episode: 63, Epsilon: 0.6563, Max Reward: 0.5564, Mean Reward: 0.5211, Accumulated Reward: 2.6056
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4900 | Architecture: ['no_op', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4908 | Architecture: ['no_op', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.4908 | Architecture: ['no_op', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.3708 | Architecture: ['no_op', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'densenet_block_5x5']
# Episode: 64, Epsilon: 0.6530, Max Reward: 0.4908, Mean Reward: 0.4384, Accumulated Reward: 2.1920
# Accuracy Reward: 0.5680 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5712 | Architecture: ['vgg_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5876 | Architecture: ['vgg_block_3x3', 'resnet_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5528 | Architecture: ['vgg_block_3x3', 'resnet_block_5x5', 'densenet_block_5x5', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.6008 | Architecture: ['vgg_block_3x3', 'resnet_block_5x5', 'densenet_block_5x5', 'inception_block_3x3', 'inception_block_3x3']
# Episode: 65, Epsilon: 0.6497, Max Reward: 0.6008, Mean Reward: 0.5761, Accumulated Reward: 2.8804
# Accuracy Reward: 0.4484 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5592 | Architecture: ['densenet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5332 | Architecture: ['densenet_block_3x3', 'inception_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5524 | Architecture: ['densenet_block_3x3', 'inception_block_5x5', 'densenet_block_3x3', 'densenet_block_5x5', 'no_op']
# Accuracy Reward: 0.5936 | Architecture: ['densenet_block_3x3', 'inception_block_5x5', 'densenet_block_3x3', 'densenet_block_5x5', 'vgg_block_3x3']
# Episode: 66, Epsilon: 0.6465, Max Reward: 0.5936, Mean Reward: 0.5374, Accumulated Reward: 2.6868
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5356 | Architecture: ['resnet_block_5x5', 'no_op', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5356 | Architecture: ['resnet_block_5x5', 'no_op', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.4948 | Architecture: ['resnet_block_5x5', 'no_op', 'inception_block_3x3', 'no_op', 'resnet_block_3x3']
# Episode: 67, Epsilon: 0.6433, Max Reward: 0.5356, Mean Reward: 0.5273, Accumulated Reward: 2.6364
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5172 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'densenet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5860 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'densenet_block_5x5', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.5892 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'densenet_block_5x5', 'vgg_block_5x5', 'inception_block_3x3']
# Episode: 68, Epsilon: 0.6400, Max Reward: 0.5892, Mean Reward: 0.5473, Accumulated Reward: 2.7364
# Accuracy Reward: 0.4484 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5620 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5916 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5960 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'resnet_block_5x5', 'densenet_block_3x3', 'no_op']
# Accuracy Reward: 0.5828 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'resnet_block_5x5', 'densenet_block_3x3', 'densenet_block_3x3']
# Episode: 69, Epsilon: 0.6368, Max Reward: 0.5960, Mean Reward: 0.5562, Accumulated Reward: 2.7808
# Accuracy Reward: 0.3496 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4776 | Architecture: ['no_op', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5500 | Architecture: ['no_op', 'densenet_block_3x3', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5500 | Architecture: ['no_op', 'densenet_block_3x3', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5500 | Architecture: ['no_op', 'densenet_block_3x3', 'inception_block_3x3', 'no_op', 'no_op']
# Episode: 70, Epsilon: 0.6337, Max Reward: 0.5500, Mean Reward: 0.4954, Accumulated Reward: 2.4772
# Accuracy Reward: 0.4584 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4584 | Architecture: ['densenet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4720 | Architecture: ['densenet_block_5x5', 'no_op', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.4720 | Architecture: ['densenet_block_5x5', 'no_op', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.4720 | Architecture: ['densenet_block_5x5', 'no_op', 'resnet_block_3x3', 'no_op', 'no_op']
# Episode: 71, Epsilon: 0.6305, Max Reward: 0.4720, Mean Reward: 0.4666, Accumulated Reward: 2.3328
# Accuracy Reward: 0.5480 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5716 | Architecture: ['vgg_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# ...
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 978, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 979, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 980, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 981, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 982, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 983, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 984, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 985, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 986, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 987, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 988, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 989, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 990, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 991, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 992, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 993, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 994, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 995, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 996, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 997, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 998, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 999, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288
# Accuracy Reward: 0.5352 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4656 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.5096 | Architecture: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Episode: 1000, Epsilon: 0.0100, Max Reward: 0.5352, Mean Reward: 0.5058, Accumulated Reward: 2.5288

# %%
def plot_q_tables(agent_q_tables, agent_action_map):
    """
    Plots the Q-tables for each agent as heatmaps.
    
    Parameters:
        agent_q_tables (list of np.ndarray): List of Q-tables for each agent.
        agent_action_map (dict): Mapping of agent indices to their action spaces.
    """
    num_agents = len(agent_q_tables)
    for agent_idx in range(num_agents):
        q_table = agent_q_tables[agent_idx]
        action_labels = [f"Action {action}" for action in agent_action_map[agent_idx]]
        
        plt.figure(figsize=(10, 6))
        sns.heatmap(q_table, annot=True, fmt=".2f", cmap="coolwarm", xticklabels=action_labels)
        plt.title(f"Q-Table for Agent {agent_idx + 1}")
        plt.xlabel("Actions")
        plt.ylabel("Layers")
        plt.show()

# Call the function to plot Q-tables
plot_q_tables([q_table], {0: list(range(len(functions)))})

# %%
best_layers = []
state = env.reset()
done = False
current_layer = 0

while not done:
    # Choose the best action based on the Q-table
    action = np.argmax(q_table[current_layer])
    best_layers.append(action)

    # Take the action
    state, reward_acc, done, current_layer = env.step(action)

print("Best architecture found:")
print(f"Acc: {reward_acc}")
print(f"Layers: {[functions[i] for i in best_layers]}")
print(f"Layers: {best_layers}")
# Out:
# Best architecture found:
# Acc: 0.5095999836921692
# Layers: ['resnet_block_5x5', 'inception_block_5x5', 'resnet_block_5x5', 'inception_block_5x5', 'no_op']
# Layers: [4, 6, 4, 6, 0]

# %%
layers_selected = [functions[i] for i in best_layers]

# %%
# Construct the best CNN model using the selected layers
model = build_cnn(layers_selected, input_shape, num_classes)

# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=retrain_patience, 
    restore_best_weights=True
)

# Retrain the model
history = model.fit(
    train_data, 
    train_labels, 
    validation_data=(val_data, val_labels), 
    epochs=retrain_epochs, 
    batch_size=batch_size, 
    callbacks=[early_stopping], 
    verbose=1
)
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 58s 44ms/step - loss: 1.6327 - accuracy: 0.4561 - val_loss: 2.1534 - val_accuracy: 0.3966
# Epoch 2/200
# 1250/1250 [==============================] - 56s 45ms/step - loss: 1.1109 - accuracy: 0.6116 - val_loss: 1.0621 - val_accuracy: 0.6287
# Epoch 3/200
# 1250/1250 [==============================] - 56s 45ms/step - loss: 0.8783 - accuracy: 0.6949 - val_loss: 1.0799 - val_accuracy: 0.6332
# Epoch 4/200
# 1250/1250 [==============================] - 57s 45ms/step - loss: 0.6942 - accuracy: 0.7566 - val_loss: 1.0388 - val_accuracy: 0.6498
# Epoch 5/200
# 1250/1250 [==============================] - 57s 45ms/step - loss: 0.4952 - accuracy: 0.8287 - val_loss: 1.1418 - val_accuracy: 0.6302
# Epoch 6/200
# 1250/1250 [==============================] - 57s 45ms/step - loss: 0.3321 - accuracy: 0.8832 - val_loss: 1.4146 - val_accuracy: 0.6197
# Epoch 7/200
# 1250/1250 [==============================] - 57s 45ms/step - loss: 0.2241 - accuracy: 0.9205 - val_loss: 1.5202 - val_accuracy: 0.6034
# Epoch 8/200
# 1250/1250 [==============================] - 57s 45ms/step - loss: 0.1670 - accuracy: 0.9404 - val_loss: 1.7506 - val_accuracy: 0.6292
# Epoch 9/200
# 1250/1250 [==============================] - 57s 45ms/step - loss: 0.1422 - accuracy: 0.9505 - val_loss: 2.1180 - val_accuracy: 0.5887
# Epoch 10/200
# 1250/1250 [==============================] - 57s 45ms/step - loss: 0.1147 - accuracy: 0.9596 - val_loss: 2.2844 - val_accuracy: 0.6147
# Epoch 11/200
# 1250/1250 [==============================] - 57s 45ms/step - loss: 0.1062 - accuracy: 0.9627 - val_loss: 2.2507 - val_accuracy: 0.6139
# Epoch 12/200
# 1250/1250 [==============================] - 56s 45ms/step - loss: 0.0993 - accuracy: 0.9668 - val_loss: 2.2103 - val_accuracy: 0.6209
# Epoch 13/200
# 1250/1250 [==============================] - 56s 45ms/step - loss: 0.0914 - accuracy: 0.9686 - val_loss: 2.3781 - val_accuracy: 0.6107
# Epoch 14/200
# 1250/1250 [==============================] - 56s 45ms/step - loss: 0.0888 - accuracy: 0.9700 - val_loss: 2.6765 - val_accuracy: 0.6210

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()

# %%
# Print final results
print("Final Results:")
print(f"Best Validation Accuracy: {max(history.history['val_accuracy']):.4f}")
print(f"Best Training Accuracy: {max(history.history['accuracy']):.4f}")
print(f"Final Validation Loss: {min(history.history['val_loss']):.4f}")
print(f"Final Training Loss: {min(history.history['loss']):.4f}")
# Out:
# Final Results:
# Best Validation Accuracy: 0.6498
# Best Training Accuracy: 0.9700
# Final Validation Loss: 1.0388
# Final Training Loss: 0.0888

# %%
test_loss, test_accuracy = model.evaluate(input_test, label_test, verbose=1)

# Print test results
print("Test Results:")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 313/313 [==============================] - 4s 14ms/step - loss: 1.0556 - accuracy: 0.6408
# Test Results:
# Test Accuracy: 0.6408
# Test Loss: 1.0556

# %%
# Get predictions for the test set
predictions = model.predict(input_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(label_test, axis=1)

# Calculate accuracy per class
num_classes = label_test.shape[1]
class_accuracies = []
for class_idx in range(num_classes):
    class_mask = (true_classes == class_idx)
    class_accuracy = np.mean(predicted_classes[class_mask] == true_classes[class_mask])
    class_accuracies.append(class_accuracy)


class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']


# Plot the accuracy per class
plt.figure(figsize=(10, 6))
plt.bar(range(num_classes), class_accuracies, color='skyblue')
plt.xlabel('Class')
plt.ylabel('Accuracy')
plt.title('Accuracy per Class')
plt.xticks(range(num_classes), class_names, rotation=45)  # Add class names and rotate for better readability
plt.ylim(0, 1)
plt.show()
# Out:
# 313/313 [==============================] - 4s 13ms/step
