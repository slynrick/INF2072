# %%
# Import necessary libraries
import tensorflow as tf
from keras import layers, models, optimizers
from keras.datasets import cifar10
from keras.utils import to_categorical
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.model_selection import train_test_split

# %%
# Set random seeds for reproducibility
np.random.seed(int(time.time()))
random.seed(int(time.time()))
tf.random.set_seed(int(time.time()))

# %%
# Load CIFAR-10 dataset
(input_train, label_train), (input_test, label_test) = cifar10.load_data()
input_train, input_test = input_train / 255.0, input_test / 255.0  # Normalize to [0, 1]
label_train, label_test = to_categorical(label_train), to_categorical(label_test)

# Split training data into training and validation sets
train_data, val_data, train_labels, val_labels = train_test_split(
    input_train, label_train, test_size=0.2, stratify=label_train, random_state=random.randint(0, 1000)
)

# %%
print(train_data.shape)
print(val_data.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
def sample_subset(data, labels, num_samples_per_class):
    sampled_data = []
    sampled_labels = []
    for class_idx in range(labels.shape[1]):  # Iterate over each class
        class_mask = labels[:, class_idx] == 1  # Find samples of the current class
        class_data = data[class_mask]
        class_labels = labels[class_mask]
        
        # Randomly sample the specified number of samples
        indices = np.random.choice(len(class_data), num_samples_per_class, replace=False)
        sampled_data.append(class_data[indices])
        sampled_labels.append(class_labels[indices])
    
    # Concatenate all sampled data and labels
    return np.concatenate(sampled_data), np.concatenate(sampled_labels)

# %%
# Hiperparâmetros
num_layers = 5  # Número de camadas ocultas
alpha = 0.1  # Learning rate
gamma = 0.9  # Discount factor
epsilon = 0.9  # Initial exploration rate
epsilon_decay = 0.995
min_epsilon = 0.01
num_episodes = 1000  # Número de episódios para treinar o agente

input_channels = 3  # For RGB images
num_classes = 10  # Example for CIFAR-10
batch_size = 32
input_shape = (batch_size, 32, 32, 3,)

patience = 5
rl_epochs = 30  # Número de épocas para treinar a rede com os dados da memória
retrain_patience = 10
retrain_epochs = 200  # Número de épocas para treinar a rede com os dados da memória

# %%
functions = [
    'no_op',
    'vgg_block_3x3', 'vgg_block_5x5',
    'resnet_block_3x3', 'resnet_block_5x5',
    'inception_block_3x3', 'inception_block_5x5',
    'densenet_block_3x3', 'densenet_block_5x5'
]
functions_size = len(functions)

# %%
# Define block implementations
def vgg_block(input_tensor, filters, kernel_size, layer_name):
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='relu', name=f"{layer_name}_1")(input_tensor)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_1")(x)  # Add Batch Normalization
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='relu', name=f"{layer_name}_2")(x)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_2")(x)  # Add Batch Normalization
    x = layers.MaxPooling2D(pool_size=(2, 2), name=f"{layer_name}_3")(x)
    return x

def resnet_block(input_tensor, filters, kernel_size, layer_name):
    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), padding='same', name=f"{layer_name}_1")(input_tensor)
    x = layers.Conv2D(filters, kernel_size, padding='same', activation='relu', name=f"{layer_name}_2")(input_tensor)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_1")(x)  # Add Batch Normalization
    x = layers.Conv2D(filters, kernel_size, padding='same', name=f"{layer_name}_3")(x)
    x = layers.BatchNormalization(name=f"{layer_name}_bn_2")(x)  # Add Batch Normalization
    x = layers.Add(name=f"{layer_name}_4")([x, shortcut])
    x = layers.Activation('relu', name=f"{layer_name}_5")(x)
    return x

def inception_block(input_tensor, kernel_size, layer_name):
    branch1 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_1")(input_tensor)
    branch2 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_2")(input_tensor)
    branch2 = layers.Conv2D(64, kernel_size, padding='same', activation='relu', name=f"{layer_name}_3")(branch2)
    branch3 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_4")(input_tensor)
    branch3 = layers.Conv2D(64, kernel_size=(kernel_size[0] + 2, kernel_size[1] + 2), padding='same', activation='relu', name=f"{layer_name}_5")(branch3)
    branch4 = layers.MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same', name=f"{layer_name}_6")(input_tensor)
    branch4 = layers.Conv2D(32, kernel_size=(1, 1), activation='relu', name=f"{layer_name}_7")(branch4)
    return layers.Concatenate(name=f"{layer_name}_8")([branch1, branch2, branch3, branch4])

def densenet_block(input_tensor, filters, kernel_size, layer_name):
    x = layers.Conv2D(filters, kernel_size, padding='same', name=f"{layer_name}_1")(input_tensor)
    x = layers.BatchNormalization(name=f"{layer_name}_2")(x)
    x = layers.ReLU(name=f"{layer_name}_3")(x)
    return layers.Concatenate(name=f"{layer_name}_4")([input_tensor, x])

# Define CNN model
def build_cnn(layers_config, input_shape, num_classes):
    input_tensor = layers.Input(shape=input_shape[1:], name="input")
    x = input_tensor
    for idx, layer in enumerate(layers_config):
        if layer == 'vgg_block_3x3':
            x = vgg_block(x, 64, (3, 3), layer_name=f"vgg_block_3x3_{idx}")
        elif layer == 'vgg_block_5x5':
            x = vgg_block(x, 64, (5, 5), layer_name=f"vgg_block_5x5_{idx}")
        elif layer == 'resnet_block_3x3':
            x = resnet_block(x, 64, (3, 3), layer_name=f"resnet_block_3x3_{idx}")
        elif layer == 'resnet_block_5x5':
            x = resnet_block(x, 64, (5, 5), layer_name=f"resnet_block_5x5_{idx}")
        elif layer == 'inception_block_3x3':
            x = inception_block(x, (3, 3), layer_name=f"inception_block_3x3_{idx}")
        elif layer == 'inception_block_5x5':
            x = inception_block(x, (5, 5), layer_name=f"inception_block_5x5_{idx}")
        elif layer == 'densenet_block_3x3':
            x = densenet_block(x, 32, (3, 3), layer_name=f"densenet_block_3x3_{idx}")
        elif layer == 'densenet_block_5x5':
            x = densenet_block(x, 32, (5, 5), layer_name=f"densenet_block_5x5_{idx}")
        elif layer == 'no_op':
            x = layers.Lambda(lambda y: y, name=f"ide_{idx}")(x)
    x = layers.Flatten(name="flatten")(x)
    output_tensor = layers.Dense(num_classes, activation='softmax', name="output")(x)
    model = models.Model(inputs=[input_tensor], outputs=[output_tensor], name='cnn_model')
    model.compile(optimizer=optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
class MultiAgentCNNEnv:
    def __init__(self, input_shape, num_classes, num_layers, agent_functions):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.agent_functions = agent_functions
        self.num_agents = len(agent_functions)
        self.layers_str = ['no_op'] * num_layers
        self.current_layer_index = 0
        self.evaluation_cache = {}

    def reset(self):
        self.layers_str = ['no_op'] * self.num_layers
        self.current_layer_index = 0
        return self.get_state()

    def step(self, agent_id, final_action):
        self.layers_str[self.current_layer_index] = self.agent_functions[agent_id][final_action]
        next_state = self.get_state()
        layers_tuple = tuple(self.layers_str)
        if layers_tuple in self.evaluation_cache:
            reward = self.evaluation_cache[layers_tuple]
        else:
            reward = self.evaluate()
            self.evaluation_cache[layers_tuple] = reward

        self.current_layer_index += 1
        done = self.current_layer_index >= self.num_layers
        return next_state, reward, done, self.current_layer_index

    def get_state(self):
        return self.layers_str

    def evaluate(self):

        # Sample 1000 random samples per class for training
        subsample_train_data, subsample_train_labels = sample_subset(train_data, train_labels, 1000)

        # Sample 250 random samples per class for validation
        subsample_val_data, subsample_val_labels = sample_subset(val_data, val_labels, 250)

        model = build_cnn(self.layers_str, self.input_shape, self.num_classes)
        
        # Early stopping callback
        early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='val_loss', 
            patience=retrain_patience, 
            restore_best_weights=True
        )
        
        history = model.fit(
            subsample_train_data, 
            subsample_train_labels,
            validation_data=(subsample_val_data, subsample_val_labels), 
            callbacks=[early_stopping],
            epochs=rl_epochs, 
            batch_size=batch_size, 
            verbose=0
        )
        
        val_accuracy = max(history.history['val_accuracy'])
        return val_accuracy

# %%
def collaborate(actions, q_values, agent_functions):
    """
    Collaborates between agents to determine the final action for the current layer.

    Parameters:
        actions (list): List of actions selected by each agent.
        q_values (list): List of Q-values corresponding to the actions of each agent.
        agent_functions (list): List of functions available to each agent.

    Returns:
        final_action (int): The index of the final action to be taken.
        selected_agent (list): The indices of the agents responsible for the final action.
    """
    final_action = None
    # Check if all Q-values are equal, in which case select a random action
    if max(q_values) == min(q_values):
        final_action = random.choice(actions)
    else:
        # Initialize a dictionary to store votes for each action
        action_votes = {action: 0 for action in range(len(agent_functions[0]))}
        # Accumulate votes based on Q-values
        for agent_idx, (action, q_value) in enumerate(zip(actions, q_values)):
            action_votes[action] += q_value
        
        # Select the action with the highest weighted vote
        final_action = max(action_votes, key=action_votes.get)

    # Find the agents responsible for the selected action
    selected_agent = [agent_idx for agent_idx, action in enumerate(actions) if action == final_action]
    if final_action == 0:
        selected_agent = list(range(len(actions)))

    return final_action, selected_agent

# %%
agent_functions = [
    ['no_op', 'vgg_block_3x3', 'vgg_block_5x5'],  # Agent 1: VGG blocks
    ['no_op', 'resnet_block_3x3', 'resnet_block_5x5'],  # Agent 2: ResNet blocks
    ['no_op', 'inception_block_3x3', 'inception_block_5x5'],  # Agent 3: Inception blocks
    ['no_op', 'densenet_block_3x3', 'densenet_block_5x5']  # Agent 4: DenseNet blocks
]

# Initialize the environment
env = MultiAgentCNNEnv(input_shape, num_classes, num_layers, agent_functions)

# Initialize Q-table for the single agent
q_tables = [np.zeros((num_layers, len(agent_functions[i]))) for i in range(len(agent_functions))]

# RL
for episode in range(num_episodes):
    state = env.reset()
    done = False
    current_layer = 0

    all_rewards = []
    while not done:
        # Each agent selects an action and retrieves its Q-value
        actions = []
        q_values = []
        for agent_idx in range(len(agent_functions)):
            if random.random() > epsilon:
                action = np.argmax(q_tables[agent_idx][current_layer])
            else:
                action = random.randint(0, len(agent_functions[agent_idx]) - 1)
            actions.append(action)
            q_values.append(q_tables[agent_idx][current_layer, action])

        # Collaborate to determine the final action
        final_action, from_agents = collaborate(actions, q_values, agent_functions)

        # Take the action and observe the next state and reward
        next_state, reward_acc, done, next_layer = env.step(from_agents[0], action)

        print(f"Accuracy Reward: {reward_acc:.4f} | Architecture: {env.layers_str}")

        reward = reward_acc  # Use accuracy as the primary reward

        all_rewards.append(reward)

        # Update the Q-tables for each agent
        for agent_idx in range(len(agent_functions)):
            if next_layer < num_layers:
                if agent_idx in from_agents:
                    q_tables[agent_idx][current_layer, actions[agent_idx]] += alpha * (
                        reward + gamma * np.max(q_tables[agent_idx][next_layer]) * (1 - done) - q_tables[agent_idx][current_layer, actions[agent_idx]]
                    )

        # Move to the next state
        state = next_state
        current_layer = next_layer

    # Decay epsilon
    epsilon = max(min_epsilon, epsilon * epsilon_decay)

    # Log episode results
    print(f"Episode: {episode + 1}, Epsilon: {epsilon:.4f}, Max Reward: {np.max(all_rewards):.4f}, Mean Reward: {np.mean(all_rewards):.4f}, Accumulated Reward: {np.sum(all_rewards):.4f}")
# Out:
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6556 | Architecture: ['vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6556 | Architecture: ['vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6856 | Architecture: ['vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op', 'vgg_block_3x3']
# Episode: 1, Epsilon: 0.8955, Max Reward: 0.6856, Mean Reward: 0.6267, Accumulated Reward: 3.1336
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['no_op', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['no_op', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5088 | Architecture: ['no_op', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5500 | Architecture: ['no_op', 'inception_block_5x5', 'no_op', 'no_op', 'vgg_block_5x5']
# Episode: 2, Epsilon: 0.8910, Max Reward: 0.5500, Mean Reward: 0.4883, Accumulated Reward: 2.4416
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5792 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6820 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.7116 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.7116 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op']
# Episode: 3, Epsilon: 0.8866, Max Reward: 0.7116, Mean Reward: 0.6506, Accumulated Reward: 3.2528
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6500 | Architecture: ['vgg_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6500 | Architecture: ['vgg_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6500 | Architecture: ['vgg_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6684 | Architecture: ['vgg_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op', 'vgg_block_3x3']
# Episode: 4, Epsilon: 0.8821, Max Reward: 0.6684, Mean Reward: 0.6351, Accumulated Reward: 3.1756
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6696 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6760 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'vgg_block_5x5']
# Episode: 5, Epsilon: 0.8777, Max Reward: 0.6760, Mean Reward: 0.6478, Accumulated Reward: 3.2388
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5660 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6440 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6440 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6348 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3']
# Episode: 6, Epsilon: 0.8733, Max Reward: 0.6440, Mean Reward: 0.6092, Accumulated Reward: 3.0460
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5716 | Architecture: ['vgg_block_5x5', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6472 | Architecture: ['vgg_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6472 | Architecture: ['vgg_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6656 | Architecture: ['vgg_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'vgg_block_3x3']
# Episode: 7, Epsilon: 0.8690, Max Reward: 0.6656, Mean Reward: 0.6178, Accumulated Reward: 3.0888
# Accuracy Reward: 0.5240 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5240 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5536 | Architecture: ['inception_block_3x3', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5768 | Architecture: ['inception_block_3x3', 'no_op', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op']
# Accuracy Reward: 0.5768 | Architecture: ['inception_block_3x3', 'no_op', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op']
# Episode: 8, Epsilon: 0.8646, Max Reward: 0.5768, Mean Reward: 0.5510, Accumulated Reward: 2.7552
# Accuracy Reward: 0.4580 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5576 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6420 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6732 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6732 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 9, Epsilon: 0.8603, Max Reward: 0.6732, Mean Reward: 0.6008, Accumulated Reward: 3.0040
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5556 | Architecture: ['no_op', 'no_op', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5556 | Architecture: ['no_op', 'no_op', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5556 | Architecture: ['no_op', 'no_op', 'vgg_block_5x5', 'no_op', 'no_op']
# Episode: 10, Epsilon: 0.8560, Max Reward: 0.5556, Mean Reward: 0.4794, Accumulated Reward: 2.3972
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6360 | Architecture: ['vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6404 | Architecture: ['vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6404 | Architecture: ['vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 11, Epsilon: 0.8517, Max Reward: 0.6404, Mean Reward: 0.6062, Accumulated Reward: 3.0312
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6676 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.7060 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'inception_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6912 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'inception_block_3x3', 'vgg_block_5x5', 'densenet_block_5x5']
# Episode: 12, Epsilon: 0.8475, Max Reward: 0.7060, Mean Reward: 0.6591, Accumulated Reward: 3.2956
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6048 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6788 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6788 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6816 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'resnet_block_3x3']
# Episode: 13, Epsilon: 0.8432, Max Reward: 0.6816, Mean Reward: 0.6425, Accumulated Reward: 3.2124
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6360 | Architecture: ['vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6360 | Architecture: ['vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6360 | Architecture: ['vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Episode: 14, Epsilon: 0.8390, Max Reward: 0.6360, Mean Reward: 0.6045, Accumulated Reward: 3.0224
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5880 | Architecture: ['vgg_block_5x5', 'no_op', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6704 | Architecture: ['vgg_block_5x5', 'no_op', 'inception_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6868 | Architecture: ['vgg_block_5x5', 'no_op', 'inception_block_3x3', 'vgg_block_5x5', 'vgg_block_5x5']
# Episode: 15, Epsilon: 0.8348, Max Reward: 0.6868, Mean Reward: 0.6119, Accumulated Reward: 3.0596
# Accuracy Reward: 0.5240 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5448 | Architecture: ['inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5716 | Architecture: ['inception_block_3x3', 'vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6728 | Architecture: ['inception_block_3x3', 'vgg_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6728 | Architecture: ['inception_block_3x3', 'vgg_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 16, Epsilon: 0.8306, Max Reward: 0.6728, Mean Reward: 0.5972, Accumulated Reward: 2.9860
# Accuracy Reward: 0.5240 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5240 | Architecture: ['inception_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5536 | Architecture: ['inception_block_3x3', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5536 | Architecture: ['inception_block_3x3', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6404 | Architecture: ['inception_block_3x3', 'no_op', 'vgg_block_3x3', 'no_op', 'vgg_block_5x5']
# Episode: 17, Epsilon: 0.8265, Max Reward: 0.6404, Mean Reward: 0.5591, Accumulated Reward: 2.7956
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6064 | Architecture: ['vgg_block_3x3', 'no_op', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6064 | Architecture: ['vgg_block_3x3', 'no_op', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6064 | Architecture: ['vgg_block_3x3', 'no_op', 'resnet_block_5x5', 'no_op', 'no_op']
# Episode: 18, Epsilon: 0.8224, Max Reward: 0.6064, Mean Reward: 0.5912, Accumulated Reward: 2.9560
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5580 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.5580 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'vgg_block_3x3', 'no_op']
# Episode: 19, Epsilon: 0.8182, Max Reward: 0.5580, Mean Reward: 0.5060, Accumulated Reward: 2.5300
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5356 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5220 | Architecture: ['resnet_block_3x3', 'resnet_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Episode: 20, Epsilon: 0.8141, Max Reward: 0.5464, Mean Reward: 0.5296, Accumulated Reward: 2.6480
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5680 | Architecture: ['no_op', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5680 | Architecture: ['no_op', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5680 | Architecture: ['no_op', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Episode: 21, Epsilon: 0.8101, Max Reward: 0.5680, Mean Reward: 0.4869, Accumulated Reward: 2.4344
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6048 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6048 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6048 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6048 | Architecture: ['vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 22, Epsilon: 0.8060, Max Reward: 0.6048, Mean Reward: 0.5975, Accumulated Reward: 2.9876
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5700 | Architecture: ['no_op', 'no_op', 'no_op', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6108 | Architecture: ['no_op', 'no_op', 'no_op', 'vgg_block_3x3', 'resnet_block_5x5']
# Episode: 23, Epsilon: 0.8020, Max Reward: 0.6108, Mean Reward: 0.4553, Accumulated Reward: 2.2764
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5452 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6036 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6036 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6012 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'densenet_block_5x5']
# Episode: 24, Epsilon: 0.7980, Max Reward: 0.6036, Mean Reward: 0.5800, Accumulated Reward: 2.9000
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6304 | Architecture: ['vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6304 | Architecture: ['vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6304 | Architecture: ['vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6304 | Architecture: ['vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 25, Epsilon: 0.7940, Max Reward: 0.6304, Mean Reward: 0.6158, Accumulated Reward: 3.0788
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5524 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5524 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5524 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5524 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Episode: 26, Epsilon: 0.7900, Max Reward: 0.5572, Mean Reward: 0.5534, Accumulated Reward: 2.7668
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5792 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5840 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6856 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'inception_block_5x5', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6988 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'inception_block_5x5', 'vgg_block_5x5', 'vgg_block_3x3']
# Episode: 27, Epsilon: 0.7861, Max Reward: 0.6988, Mean Reward: 0.6232, Accumulated Reward: 3.1160
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6500 | Architecture: ['vgg_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6684 | Architecture: ['vgg_block_5x5', 'vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6684 | Architecture: ['vgg_block_5x5', 'vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6768 | Architecture: ['vgg_block_5x5', 'vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'vgg_block_5x5']
# Episode: 28, Epsilon: 0.7821, Max Reward: 0.6768, Mean Reward: 0.6442, Accumulated Reward: 3.2208
# Accuracy Reward: 0.5220 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5268 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5572 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5572 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5572 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'inception_block_5x5', 'no_op', 'no_op']
# Episode: 29, Epsilon: 0.7782, Max Reward: 0.5572, Mean Reward: 0.5441, Accumulated Reward: 2.7204
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5720 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6384 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'resnet_block_5x5', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6384 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'resnet_block_5x5', 'vgg_block_5x5', 'no_op']
# Episode: 30, Epsilon: 0.7743, Max Reward: 0.6384, Mean Reward: 0.5862, Accumulated Reward: 2.9312
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4684 | Architecture: ['no_op', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5656 | Architecture: ['no_op', 'densenet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5656 | Architecture: ['no_op', 'densenet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5788 | Architecture: ['no_op', 'densenet_block_3x3', 'vgg_block_5x5', 'no_op', 'resnet_block_3x3']
# Episode: 31, Epsilon: 0.7705, Max Reward: 0.5788, Mean Reward: 0.5087, Accumulated Reward: 2.5436
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5472 | Architecture: ['no_op', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6476 | Architecture: ['no_op', 'vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6460 | Architecture: ['no_op', 'vgg_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6460 | Architecture: ['no_op', 'vgg_block_5x5', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op']
# Episode: 32, Epsilon: 0.7666, Max Reward: 0.6476, Mean Reward: 0.5704, Accumulated Reward: 2.8520
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5512 | Architecture: ['no_op', 'no_op', 'no_op', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.5512 | Architecture: ['no_op', 'no_op', 'no_op', 'vgg_block_5x5', 'no_op']
# Episode: 33, Epsilon: 0.7628, Max Reward: 0.5512, Mean Reward: 0.4396, Accumulated Reward: 2.1980
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6360 | Architecture: ['vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6360 | Architecture: ['vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6656 | Architecture: ['vgg_block_5x5', 'no_op', 'vgg_block_3x3', 'no_op', 'vgg_block_5x5']
# Episode: 34, Epsilon: 0.7590, Max Reward: 0.6656, Mean Reward: 0.6104, Accumulated Reward: 3.0520
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5792 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6980 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6828 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'vgg_block_5x5', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.6888 | Architecture: ['vgg_block_3x3', 'inception_block_5x5', 'vgg_block_5x5', 'resnet_block_5x5', 'densenet_block_5x5']
# Episode: 35, Epsilon: 0.7552, Max Reward: 0.6980, Mean Reward: 0.6434, Accumulated Reward: 3.2172
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6372 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6796 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6960 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'vgg_block_5x5', 'vgg_block_5x5']
# Episode: 36, Epsilon: 0.7514, Max Reward: 0.6960, Mean Reward: 0.6487, Accumulated Reward: 3.2436
# Accuracy Reward: 0.5220 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5148 | Architecture: ['inception_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5032 | Architecture: ['inception_block_5x5', 'resnet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5608 | Architecture: ['inception_block_5x5', 'resnet_block_3x3', 'inception_block_5x5', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.5880 | Architecture: ['inception_block_5x5', 'resnet_block_3x3', 'inception_block_5x5', 'vgg_block_3x3', 'resnet_block_3x3']
# Episode: 37, Epsilon: 0.7476, Max Reward: 0.5880, Mean Reward: 0.5378, Accumulated Reward: 2.6888
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5132 | Architecture: ['no_op', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5624 | Architecture: ['no_op', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5624 | Architecture: ['no_op', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6564 | Architecture: ['no_op', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'vgg_block_5x5']
# Episode: 38, Epsilon: 0.7439, Max Reward: 0.6564, Mean Reward: 0.5319, Accumulated Reward: 2.6596
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6304 | Architecture: ['vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6244 | Architecture: ['vgg_block_5x5', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6528 | Architecture: ['vgg_block_5x5', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6584 | Architecture: ['vgg_block_5x5', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_5x5', 'densenet_block_3x3']
# Episode: 39, Epsilon: 0.7402, Max Reward: 0.6584, Mean Reward: 0.6246, Accumulated Reward: 3.1232
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6756 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6692 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6692 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6724 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'vgg_block_3x3']
# Episode: 40, Epsilon: 0.7365, Max Reward: 0.6756, Mean Reward: 0.6510, Accumulated Reward: 3.2548
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6756 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6656 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6656 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.7092 | Architecture: ['vgg_block_3x3', 'vgg_block_5x5', 'inception_block_3x3', 'no_op', 'vgg_block_5x5']
# Episode: 41, Epsilon: 0.7328, Max Reward: 0.7092, Mean Reward: 0.6569, Accumulated Reward: 3.2844
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6884 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.7000 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_5x5', 'inception_block_5x5', 'no_op']
# Accuracy Reward: 0.6700 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_5x5', 'inception_block_5x5', 'vgg_block_3x3']
# Episode: 42, Epsilon: 0.7291, Max Reward: 0.7000, Mean Reward: 0.6578, Accumulated Reward: 3.2892
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5524 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5708 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5708 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5708 | Architecture: ['vgg_block_5x5', 'densenet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op']
# Episode: 43, Epsilon: 0.7255, Max Reward: 0.5708, Mean Reward: 0.5644, Accumulated Reward: 2.8220
# Accuracy Reward: 0.4580 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5784 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5784 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5760 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'no_op', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.5760 | Architecture: ['densenet_block_3x3', 'vgg_block_5x5', 'no_op', 'resnet_block_5x5', 'no_op']
# Episode: 44, Epsilon: 0.7219, Max Reward: 0.5784, Mean Reward: 0.5534, Accumulated Reward: 2.7668
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5672 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5672 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6568 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6568 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op']
# Episode: 45, Epsilon: 0.7183, Max Reward: 0.6568, Mean Reward: 0.5989, Accumulated Reward: 2.9944
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5776 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'vgg_block_3x3']
# Episode: 46, Epsilon: 0.7147, Max Reward: 0.5776, Mean Reward: 0.5032, Accumulated Reward: 2.5160
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6044 | Architecture: ['vgg_block_3x3', 'no_op', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6044 | Architecture: ['vgg_block_3x3', 'no_op', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6044 | Architecture: ['vgg_block_3x3', 'no_op', 'resnet_block_3x3', 'no_op', 'no_op']
# Episode: 47, Epsilon: 0.7111, Max Reward: 0.6044, Mean Reward: 0.5900, Accumulated Reward: 2.9500
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6372 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6764 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6652 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'vgg_block_3x3', 'densenet_block_3x3']
# Episode: 48, Epsilon: 0.7075, Max Reward: 0.6764, Mean Reward: 0.6419, Accumulated Reward: 3.2096
# Accuracy Reward: 0.5220 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5500 | Architecture: ['inception_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5456 | Architecture: ['inception_block_5x5', 'vgg_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6264 | Architecture: ['inception_block_5x5', 'vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6264 | Architecture: ['inception_block_5x5', 'vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op']
# Episode: 49, Epsilon: 0.7040, Max Reward: 0.6264, Mean Reward: 0.5741, Accumulated Reward: 2.8704
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Episode: 50, Epsilon: 0.7005, Max Reward: 0.6628, Mean Reward: 0.6438, Accumulated Reward: 3.2192
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5812 | Architecture: ['vgg_block_3x3', 'no_op', 'densenet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5712 | Architecture: ['vgg_block_3x3', 'no_op', 'densenet_block_3x3', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.6880 | Architecture: ['vgg_block_3x3', 'no_op', 'densenet_block_3x3', 'inception_block_3x3', 'vgg_block_5x5']
# Episode: 51, Epsilon: 0.6970, Max Reward: 0.6880, Mean Reward: 0.5954, Accumulated Reward: 2.9772
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5552 | Architecture: ['no_op', 'no_op', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5664 | Architecture: ['no_op', 'no_op', 'resnet_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6736 | Architecture: ['no_op', 'no_op', 'resnet_block_3x3', 'vgg_block_3x3', 'vgg_block_5x5']
# Episode: 52, Epsilon: 0.6935, Max Reward: 0.6736, Mean Reward: 0.5051, Accumulated Reward: 2.5256
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5136 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'resnet_block_5x5', 'no_op']
# Accuracy Reward: 0.5276 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'resnet_block_5x5', 'resnet_block_3x3']
# Episode: 53, Epsilon: 0.6900, Max Reward: 0.5276, Mean Reward: 0.4910, Accumulated Reward: 2.4552
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5832 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'vgg_block_3x3']
# Episode: 54, Epsilon: 0.6866, Max Reward: 0.5832, Mean Reward: 0.4088, Accumulated Reward: 2.0440
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5660 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6440 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6440 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6148 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'inception_block_5x5']
# Episode: 55, Epsilon: 0.6831, Max Reward: 0.6440, Mean Reward: 0.6052, Accumulated Reward: 3.0260
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5244 | Architecture: ['no_op', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5612 | Architecture: ['no_op', 'resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5612 | Architecture: ['no_op', 'resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5812 | Architecture: ['no_op', 'resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'densenet_block_3x3']
# Episode: 56, Epsilon: 0.6797, Max Reward: 0.5812, Mean Reward: 0.5186, Accumulated Reward: 2.5932
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5488 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5892 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5892 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5892 | Architecture: ['resnet_block_3x3', 'inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Episode: 57, Epsilon: 0.6763, Max Reward: 0.5892, Mean Reward: 0.5726, Accumulated Reward: 2.8628
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6536 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6536 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'vgg_block_3x3', 'no_op']
# Episode: 58, Epsilon: 0.6729, Max Reward: 0.6536, Mean Reward: 0.6025, Accumulated Reward: 3.0124
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5452 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6036 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6568 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6616 | Architecture: ['resnet_block_3x3', 'inception_block_3x3', 'vgg_block_3x3', 'vgg_block_5x5', 'vgg_block_5x5']
# Episode: 59, Epsilon: 0.6696, Max Reward: 0.6616, Mean Reward: 0.6027, Accumulated Reward: 3.0136
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5672 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6432 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6432 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6588 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'inception_block_3x3']
# Episode: 60, Epsilon: 0.6662, Max Reward: 0.6588, Mean Reward: 0.6118, Accumulated Reward: 3.0588
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5428 | Architecture: ['resnet_block_5x5', 'no_op', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5428 | Architecture: ['resnet_block_5x5', 'no_op', 'inception_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.5156 | Architecture: ['resnet_block_5x5', 'no_op', 'inception_block_5x5', 'no_op', 'inception_block_5x5']
# Episode: 61, Epsilon: 0.6629, Max Reward: 0.5428, Mean Reward: 0.5346, Accumulated Reward: 2.6732
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5672 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5672 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6380 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6840 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'vgg_block_3x3', 'vgg_block_3x3']
# Episode: 62, Epsilon: 0.6596, Max Reward: 0.6840, Mean Reward: 0.6006, Accumulated Reward: 3.0028
# Accuracy Reward: 0.5220 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5092 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5632 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5632 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6424 | Architecture: ['inception_block_5x5', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'vgg_block_3x3']
# Episode: 63, Epsilon: 0.6563, Max Reward: 0.6424, Mean Reward: 0.5600, Accumulated Reward: 2.8000
# Accuracy Reward: 0.4580 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5576 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6420 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6420 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6420 | Architecture: ['densenet_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Episode: 64, Epsilon: 0.6530, Max Reward: 0.6420, Mean Reward: 0.5883, Accumulated Reward: 2.9416
# Accuracy Reward: 0.5572 | Architecture: ['vgg_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5660 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6416 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6708 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_5x5', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6708 | Architecture: ['vgg_block_5x5', 'resnet_block_5x5', 'vgg_block_5x5', 'vgg_block_3x3', 'no_op']
# Episode: 65, Epsilon: 0.6497, Max Reward: 0.6708, Mean Reward: 0.6213, Accumulated Reward: 3.1064
# Accuracy Reward: 0.4580 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.4580 | Architecture: ['densenet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5744 | Architecture: ['densenet_block_3x3', 'no_op', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6552 | Architecture: ['densenet_block_3x3', 'no_op', 'vgg_block_5x5', 'vgg_block_5x5', 'no_op']
# Accuracy Reward: 0.6964 | Architecture: ['densenet_block_3x3', 'no_op', 'vgg_block_5x5', 'vgg_block_5x5', 'vgg_block_3x3']
# Episode: 66, Epsilon: 0.6465, Max Reward: 0.6964, Mean Reward: 0.5684, Accumulated Reward: 2.8420
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5904 | Architecture: ['vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6556 | Architecture: ['vgg_block_3x3', 'resnet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6556 | Architecture: ['vgg_block_3x3', 'resnet_block_3x3', 'vgg_block_5x5', 'no_op', 'no_op']
# Accuracy Reward: 0.6836 | Architecture: ['vgg_block_3x3', 'resnet_block_3x3', 'vgg_block_5x5', 'no_op', 'vgg_block_3x3']
# Episode: 67, Epsilon: 0.6433, Max Reward: 0.6836, Mean Reward: 0.6307, Accumulated Reward: 3.1536
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5560 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5164 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'resnet_block_3x3', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'resnet_block_3x3', 'inception_block_3x3', 'no_op']
# Episode: 68, Epsilon: 0.6400, Max Reward: 0.5560, Mean Reward: 0.5382, Accumulated Reward: 2.6908
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5472 | Architecture: ['no_op', 'vgg_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6476 | Architecture: ['no_op', 'vgg_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6216 | Architecture: ['no_op', 'vgg_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.6216 | Architecture: ['no_op', 'vgg_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'no_op']
# Episode: 69, Epsilon: 0.6368, Max Reward: 0.6476, Mean Reward: 0.5606, Accumulated Reward: 2.8032
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5560 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5560 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5560 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5560 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Episode: 70, Epsilon: 0.6337, Max Reward: 0.5560, Mean Reward: 0.5541, Accumulated Reward: 2.7704
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.3652 | Architecture: ['no_op', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5188 | Architecture: ['no_op', 'no_op', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5188 | Architecture: ['no_op', 'no_op', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5188 | Architecture: ['no_op', 'no_op', 'inception_block_3x3', 'no_op', 'no_op']
# Episode: 71, Epsilon: 0.6305, Max Reward: 0.5188, Mean Reward: 0.4574, Accumulated Reward: 2.2868
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5560 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5516 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5860 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.5788 | Architecture: ['resnet_block_3x3', 'resnet_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'densenet_block_5x5']
# Episode: 72, Epsilon: 0.6273, Max Reward: 0.5860, Mean Reward: 0.5638, Accumulated Reward: 2.8188
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5672 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5672 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5672 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6392 | Architecture: ['resnet_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'vgg_block_3x3']
# Episode: 73, Epsilon: 0.6242, Max Reward: 0.6392, Mean Reward: 0.5774, Accumulated Reward: 2.8872
# Accuracy Reward: 0.5360 | Architecture: ['resnet_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5548 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5464 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'inception_block_3x3', 'no_op']
# Accuracy Reward: 0.6224 | Architecture: ['resnet_block_5x5', 'vgg_block_3x3', 'inception_block_3x3', 'inception_block_3x3', 'vgg_block_3x3']
# Episode: 74, Epsilon: 0.6211, Max Reward: 0.6224, Mean Reward: 0.5612, Accumulated Reward: 2.8060
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6372 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6372 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6372 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'resnet_block_3x3', 'no_op', 'no_op']
# Episode: 75, Epsilon: 0.6180, Max Reward: 0.6624, Mean Reward: 0.6285, Accumulated Reward: 3.1424
# Accuracy Reward: 0.5220 | Architecture: ['inception_block_5x5', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5268 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.5480 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.5480 | Architecture: ['inception_block_5x5', 'inception_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# ...
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 976, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 977, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 978, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 979, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 980, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 981, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 982, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 983, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 984, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 985, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 986, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 987, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 988, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 989, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 990, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 991, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 992, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 993, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 994, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 995, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 996, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 997, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 998, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 999, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560
# Accuracy Reward: 0.5684 | Architecture: ['vgg_block_3x3', 'no_op', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6624 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op', 'no_op']
# Accuracy Reward: 0.6628 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Accuracy Reward: 0.6812 | Architecture: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Episode: 1000, Epsilon: 0.0100, Max Reward: 0.6812, Mean Reward: 0.6512, Accumulated Reward: 3.2560

# %%
def plot_q_tables(agent_q_tables, agent_functions):
    """
    Plots the Q-tables for each agent as heatmaps.
    
    Parameters:
        agent_q_tables (list of np.ndarray): List of Q-tables for each agent.
        agent_functions (list of list): List of functions available to each agent.
    """
    num_agents = len(agent_q_tables)
    for agent_idx in range(num_agents):
        q_table = agent_q_tables[agent_idx]
        action_labels = agent_functions[agent_idx]
        
        plt.figure(figsize=(10, 6))
        sns.heatmap(q_table, annot=True, fmt=".2f", cmap="coolwarm", xticklabels=action_labels)
        plt.title(f"Q-Table for Agent {agent_idx + 1}")
        plt.xlabel("Actions")
        plt.ylabel("Layers")
        plt.show()

# Call the function to plot Q-tables
plot_q_tables(q_tables, agent_functions)

# %%
best_layers = []
state = env.reset()
done = False
current_layer = 0

while not done:
    # Each agent selects the best action based on its Q-table
    actions = [np.argmax(q_tables[agent_idx][current_layer]) for agent_idx in range(len(agent_functions))]
    q_values = [q_tables[agent_idx][current_layer, actions[agent_idx]] for agent_idx in range(len(agent_functions))]

    # Collaborate to determine the final action
    final_action, from_agents = collaborate(actions, q_values, agent_functions)
    best_layers.append(final_action)

    # Take the action
    state, reward_acc, done, current_layer = env.step(from_agents[0], final_action)

print("Best architecture found:")
print(f"Acc: {reward_acc}")
print(f"Layers: {[functions[i] for i in best_layers]}")
print(f"Layers: {best_layers}")
# Out:
# Best architecture found:
# Acc: 0.6812000274658203
# Layers: ['vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'vgg_block_3x3', 'no_op']
# Layers: [1, 1, 1, 1, 0]

# %%
layers_selected = [functions[i] for i in best_layers]

# %%
# Construct the best CNN model using the selected layers
model = build_cnn(layers_selected, input_shape, num_classes)

# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=retrain_patience, 
    restore_best_weights=True
)

# Retrain the model
history = model.fit(
    train_data, 
    train_labels, 
    validation_data=(val_data, val_labels), 
    epochs=retrain_epochs, 
    batch_size=batch_size, 
    callbacks=[early_stopping], 
    verbose=1
)
# Out:
# Epoch 1/200
# 1250/1250 [==============================] - 19s 13ms/step - loss: 1.4163 - accuracy: 0.5010 - val_loss: 1.1591 - val_accuracy: 0.5931
# Epoch 2/200
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.9005 - accuracy: 0.6836 - val_loss: 0.8124 - val_accuracy: 0.7193
# Epoch 3/200
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.7147 - accuracy: 0.7524 - val_loss: 1.0860 - val_accuracy: 0.6562
# Epoch 4/200
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.5985 - accuracy: 0.7909 - val_loss: 0.6933 - val_accuracy: 0.7644
# Epoch 5/200
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.5040 - accuracy: 0.8247 - val_loss: 0.6539 - val_accuracy: 0.7806
# Epoch 6/200
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.4286 - accuracy: 0.8485 - val_loss: 0.6951 - val_accuracy: 0.7761
# Epoch 7/200
# 1250/1250 [==============================] - 16s 12ms/step - loss: 0.3630 - accuracy: 0.8727 - val_loss: 0.6275 - val_accuracy: 0.7987
# Epoch 8/200
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.3048 - accuracy: 0.8925 - val_loss: 0.7722 - val_accuracy: 0.7640
# Epoch 9/200
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.2558 - accuracy: 0.9105 - val_loss: 0.7070 - val_accuracy: 0.7967
# Epoch 10/200
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.2123 - accuracy: 0.9246 - val_loss: 0.7414 - val_accuracy: 0.7959
# Epoch 11/200
# 1250/1250 [==============================] - 16s 12ms/step - loss: 0.1871 - accuracy: 0.9335 - val_loss: 0.7838 - val_accuracy: 0.7917
# Epoch 12/200
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.1624 - accuracy: 0.9423 - val_loss: 0.7831 - val_accuracy: 0.7980
# Epoch 13/200
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.1476 - accuracy: 0.9476 - val_loss: 0.8027 - val_accuracy: 0.8012
# Epoch 14/200
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.1183 - accuracy: 0.9587 - val_loss: 0.9586 - val_accuracy: 0.7767
# Epoch 15/200
# 1250/1250 [==============================] - 16s 12ms/step - loss: 0.1191 - accuracy: 0.9567 - val_loss: 0.8540 - val_accuracy: 0.8076
# Epoch 16/200
# 1250/1250 [==============================] - 16s 13ms/step - loss: 0.0998 - accuracy: 0.9644 - val_loss: 0.9136 - val_accuracy: 0.7937
# Epoch 17/200
# 1250/1250 [==============================] - 16s 12ms/step - loss: 0.1003 - accuracy: 0.9645 - val_loss: 0.9762 - val_accuracy: 0.7916

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()

# %%
# Print final results
print("Final Results:")
print(f"Best Validation Accuracy: {max(history.history['val_accuracy']):.4f}")
print(f"Best Training Accuracy: {max(history.history['accuracy']):.4f}")
print(f"Final Validation Loss: {min(history.history['val_loss']):.4f}")
print(f"Final Training Loss: {min(history.history['loss']):.4f}")
# Out:
# Final Results:
# Best Validation Accuracy: 0.8076
# Best Training Accuracy: 0.9645
# Final Validation Loss: 0.6275
# Final Training Loss: 0.0998

# %%
test_loss, test_accuracy = model.evaluate(input_test, label_test, verbose=1)

# Print test results
print("Test Results:")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.6376 - accuracy: 0.7999
# Test Results:
# Test Accuracy: 0.7999
# Test Loss: 0.6376

# %%
# Get predictions for the test set
predictions = model.predict(input_test)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(label_test, axis=1)

# Calculate accuracy per class
num_classes = label_test.shape[1]
class_accuracies = []
for class_idx in range(num_classes):
    class_mask = (true_classes == class_idx)
    class_accuracy = np.mean(predicted_classes[class_mask] == true_classes[class_mask])
    class_accuracies.append(class_accuracy)


class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']


# Plot the accuracy per class
plt.figure(figsize=(10, 6))
plt.bar(range(num_classes), class_accuracies, color='skyblue')
plt.xlabel('Class')
plt.ylabel('Accuracy')
plt.title('Accuracy per Class')
plt.xticks(range(num_classes), class_names, rotation=45)  # Add class names and rotate for better readability
plt.ylim(0, 1)
plt.show()
# Out:
# 313/313 [==============================] - 2s 4ms/step
